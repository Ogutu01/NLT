# %% [markdown]
# ## **WORD VECTORIZATION**

# %% [markdown]
# Imporing every library necessary for this action.

# %%
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.manifold import TSNE
from nltk.tokenize import word_tokenize
nltk.download('punkt', quiet = True)
np.random.seed(0)

# %% [markdown]
# The songs are contained within the lyrics data subdirectory, contained within the same folder as this practice project. Each song is stored in a single file, with files ranging from song1.txt to song20.txt.
#
# To make it easy to read in all of the documents, use a list comprehension to create a list containing the name of every single song file in the cell below.

# %%
filenames = [f"song{str(i)}.txt" for i in range(1, 21)]
filenames
# Out:
# ['song1.txt',
#  'song2.txt',
#  'song3.txt',
#  'song4.txt',
#  'song5.txt',
#  'song6.txt',
#  'song7.txt',
#  'song8.txt',
#  'song9.txt',
#  'song10.txt',
#  'song11.txt',
#  'song12.txt',
#  'song13.txt',
#  'song14.txt',
#  'song15.txt',
#  'song16.txt',
#  'song17.txt',
#  'song18.txt',
#  'song19.txt',
#  'song20.txt']

# %% [markdown]
# Next, we import a single song to see what our text looks like so that we can make sure we clean and tokenize it correctly.
#
# The code in the cell below to reads in the lyrics from song18.txt as a list of lines, just using vanilla Python.

# %%
with open ("lyrics data/song18.txt") as f:
    test_song = f.readlines()

test_song
# Out:
# ['[Kendrick Lamar:]\n',
#  "Two wrongs don't make us right away\n",
#  "Tell me something's wrong\n",
#  'Party all of our lives away\n',
#  'To take you on\n',
#  '[Zacari:]\n',
#  'Oh, baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'All night (all night, all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n',
#  'All night (all night, all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n',
#  '[Babes Wodumo:]\n',
#  'Oh my word oh my gosh oh my word (Oh my gosh)\n',
#  'Oh my word oh my gosh oh my word (Oh my gosh)\n',
#  'Oh my word oh my gosh oh my word (Oh my gosh)\n',
#  'Oh my word oh my gosh oh my word (Oh my gosh)\n',
#  'Everybody say kikiritikiki (kikiritikiki)\n',
#  'Everybody say kikiritikiki (kikiritikiki)\n',
#  'Everybody say kikiritikiki (kikiritikiki)\n',
#  'Everybody say kikiritikiki (kikiritikiki)\n',
#  "Ung'bambe, ung'dedele. Ung'bhasobhe, ung'gudluke\n",
#  "Ung'bambe, ung'dedele. Ung'bhasobhe, ung'gudluke\n",
#  "Ung'bambe, ung'dedele. Ung'bhasobhe, ung'gudluke\n",
#  "Ung'bambe, ung'dedele. Ung'bhasobhe, ung'gudluke\n",
#  '[Zacari:]\n',
#  'Baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'All night (all night all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n',
#  'All night (all night all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n',
#  '[Kendrick Lamar:]\n',
#  '(We go)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  'High up (High up)\n',
#  '[?]\n',
#  '[Zacari:]\n',
#  'Baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I want you\n',
#  'Baby I need you\n',
#  'I wanna see you\n',
#  'Baby I wanna go out yeah\n',
#  'Baby I wanna go out yeah\n',
#  'All night (all night all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n',
#  'All night (all night all night)\n',
#  'All night\n',
#  "Your body's on fire\n",
#  'And your drinks on ice\n']

# %% [markdown]
# ## **Tokenizing our Data**

# %% [markdown]
# Before we can create a bag of words or vectorize each document, we need to clean it up and split each song into an array of individual words.
#
# Before we tokenize, however, we need to do one more step! Computers are very particular about strings. If we tokenized our data in its current state, we would run into the following problems:
#
# Counting things that aren't actually words. In the example above, "[Kendrick Lamar:]" is a note specifying who is speaking, not a lyric contained in the actual song, so it should be removed.
# Punctuation and capitalization would mess up our word counts. To the Python interpreter, `all`, `All`, and `(all` are unique words, and would all be counted separately. We need to remove punctuation and capitalization, so that all words will be counted correctly.
# Before we tokenize our songs, we'll do only a small manual bit of cleaning.
#
# In the cell below, we write a function that will:
#
# - Remove lines that just contain ['artist names']
# - Join the list of strings into one big string for the entire song
# - Remove newline characters \n
# - Remove the following punctuation marks: ",.'?!()"
# - Make every word lowercase

# %%
def clean_song(song):
    clean_lines = [line for line in song if "[" not in line and "]" not in line]
    clean_song = " ".join(clean_lines)

    for symbol in ",.'?!()":
        clean_song = clean_song.replace(symbol, "")

    clean_song = clean_song.replace("\n", " ")

    return clean_song.lower()

# %%
clean_test_song = clean_song(test_song)
print(clean_test_song)
# Out:
# two wrongs dont make us right away  tell me somethings wrong  party all of our lives away  to take you on  oh baby i want you  baby i need you  i wanna see you  baby i wanna go out yeah  baby i wanna go out yeah  baby i want you  baby i need you  i wanna see you  baby i wanna go out yeah  baby i wanna go out yeah  all night all night all night  all night  your bodys on fire  and your drinks on ice  all night all night all night  all night  your bodys on fire  and your drinks on ice  oh my word oh my gosh oh my word oh my gosh  oh my word oh my gosh oh my word oh my gosh  oh my word oh my gosh oh my word oh my gosh  oh my word oh my gosh oh my word oh my gosh  everybody say kikiritikiki kikiritikiki  everybody say kikiritikiki kikiritikiki  everybody say kikiritikiki kikiritikiki  everybody say kikiritikiki kikiritikiki  ungbambe ungdedele ungbhasobhe unggudluke  ungbambe ungdedele ungbhasobhe unggudluke  ungbambe ungdedele ungbhasobhe unggudluke  ungbambe ungdedele ungbhasobhe unggudluke  baby i want you  baby i need you  i wanna see you  baby i wanna go out yeah  baby i wanna go out yeah  baby i want you  baby i need you  i wanna see you  baby i wanna go out yeah  baby i wanna go out yeah  all night all night all night  all night  your bodys on fire  and your drinks on ice  all night all night all night  all night  your bodys on fire  and your drinks on ice  we go  high up high up  high up high up  high up high up  high up high up  high up high up  high up high up  high up high up  high up high up  baby i want you  baby i need you  i wanna see you  baby i wanna go out yeah  baby i wanna go out yeah  baby i want you  baby i need you  i wanna see you  baby i wanna go out yeah  baby i wanna go out yeah  all night all night all night  all night  your bodys on fire  and your drinks on ice  all night all night all night  all night  your bodys on fire  and your drinks on ice

# %% [markdown]
# Now, we can use 'nltks `word_tokenize()` function on the song string to get a fully tokenized version of the song.

# %%
tokenized_test_song = word_tokenize(clean_test_song)
tokenized_test_song[:10]
# Out:
# ['two',
#  'wrongs',
#  'dont',
#  'make',
#  'us',
#  'right',
#  'away',
#  'tell',
#  'me',
#  'somethings']

# %% [markdown]
# ## **Count Vectorization**

# %% [markdown]
# Machine Learning algorithms don't understand strings. However, they do understand math, which means they understand vectors and matrices. By `Vectorizing` the text, we just convert the entire text into a vector, where each element in the vector represents a different word.
#
# Consider the following example:
#
# <center>"I scream, you scream, we all scream for ice cream."</center>
#
# | 'aardvark' | 'apple' | [...] | 'I' | 'you' | 'scream' | 'we' | 'all' | 'for' | 'ice' | 'cream' | [...] | 'xylophone' | 'zebra' |
# |:----------:|:-------:|:-----:|:---:|:-----:|:--------:|:----:|:-----:|:-----:|:-----:|:-------:|:-----:|:-----------:|:-------:|
# |      0     |    0    |   0   |  1  |   1   |     3    |   1  |   1   |   1   |   1   |    1    |   0   |      0      |    0    |
#
# This is called a `Sparse Representation`, since the strong majority of the columns will have a value of 0.
#
# Alternatively, we can represent this sentence as a plain old Python dictionary of word frequency counts:
#
# ```python
#
# BoW = {
#     'I':1,
#     'you':1,
#     'scream':3,
#     'we':1,
#     'all':1,
#     'for':1,
#     'ice':1,
#     'cream':1
# }
#
# ```
# Both of these are examples of **Count Vectorization**. They allow us to represent a sentence as a vector, with each element in the vector corresponding to how many times that word is used.

# %% [markdown]
# create a function that takes in a tokenized, cleaned song and returns a count vectorized representation of it as a Python dictionary.
#
# Hint: We'll use `set()` since we'll need each unique word in the tokenized song.

# %%
def count_vectorize(tokenized_song):
    unique_words = set(tokenized_song)

    song_dict = {word : 0 for word in unique_words}

    for word in tokenized_song:
        song_dict[word] += 1

    return song_dict

# %%
test_vectorized = count_vectorize(tokenized_test_song)
print(test_vectorized)
# Out:
# {'kikiritikiki': 8, 'all': 25, 'bodys': 6, 'oh': 17, 'night': 24, 'away': 2, 'we': 1, 'fire': 6, 'ice': 6, 'take': 1, 'yeah': 12, 'word': 8, 'out': 12, 'to': 1, 'want': 6, 'up': 16, 'your': 12, 'gosh': 8, 'high': 16, 'i': 30, 'see': 6, 'and': 6, 'ungbambe': 4, 'ungbhasobhe': 4, 'right': 1, 'wrongs': 1, 'na': 18, 'go': 13, 'on': 13, 'you': 19, 'everybody': 4, 'two': 1, 'wrong': 1, 'unggudluke': 4, 'need': 6, 'say': 4, 'somethings': 1, 'me': 1, 'party': 1, 'ungdedele': 4, 'wan': 18, 'my': 16, 'us': 1, 'lives': 1, 'baby': 24, 'of': 1, 'dont': 1, 'tell': 1, 'make': 1, 'drinks': 6, 'our': 1}

# %% [markdown]
# ## **TF-IDF**

# %% [markdown]
# We just calculated our Term Frequency above with Count Vectorization!
#
# In the cell below, we complete a function that takes in a list of tokenized songs, with each item in the list being a clean, tokenized version of the song. The function should return a dictionary containing the inverse document frequency values for each word.
#
# The formula for Inverse Document Frequency is:
# <br>
# <br>
# $$\large \text{IDF}(t) =  log_e(\frac{\text{Total Number of Documents}}{\text{Number of Documents with } t \text{ in it}})$$

# %%
def inverse_document_frequency(list_of_token_songs):

    num_docs = len(list_of_token_songs)

    unique_words = set([item for sublist in list_of_token_songs for item in sublist])

    inv_doc_freq = {word : 0 for word in unique_words}

    for word in unique_words:
        num_docs_with_word = 0
        for song_tokens in list_of_token_songs:
            if word in song_tokens:
                num_docs_with_word += 1
        inv_doc_freq[word] = np.log(num_docs / num_docs_with_word)

    return inv_doc_freq

# %% [markdown]
# In the cell below, complete the `tf_idf()` function. This function should take in a list of tokenized songs, just as the `inverse_document_frequency()` function did. This function returns a new list of dictionaries, with each dictionary containing the tf-idf vectorized representation of a corresponding song document. You'll need to calculate the term frequency for each song using the `count_vectorize()` function we defined above.
#
# **_NOTE:_** Each document should contain the full vocabulary of the entire combined corpus! So, even if a song doesn't have the word "kikiritikiki" (a vocalization in our test song), it should have a dictionary entry with that word as the key and `0` as the value.

# %%
def tf_idf(list_of_token_songs):
    
    unique_words = set({item for sublist in list_of_token_songs for item in sublist})

    idf = inverse_document_frequency(list_of_token_songs)

    tf_idf_list_of_dicts = []

    for song_tokens in list_of_token_songs:
        song_tf = count_vectorize(song_tokens)
        doc_tf_idf = {word : 0 for word in unique_words}

        for word in unique_words:
            if word in song_tokens:
                doc_tf_idf[word] = song_tf[word] * idf[word]
            else:
                doc_tf_idf[word] = 0
        tf_idf_list_of_dicts.append(doc_tf_idf)

    return tf_idf_list_of_dicts

# %%
def main(filenames):

    all_songs = []

    for song in filenames:
        with open(f"lyrics data/{song}") as f:
            song_lyrics = f.readlines()
            all_songs.append(song_lyrics)

    all_song_tokens = []

    for song in all_songs:
        song_tokens = word_tokenize(clean_song(song))
        all_song_tokens.append(song_tokens)

    tf_idf_all_docs = tf_idf(all_song_tokens)
    
    return tf_idf_all_docs

# %%
tf_idf_all_docs = main(filenames)
tf_idf_all_docs[:3]
# Out:
# [{'ever': 0,
#   'adds': 11.982929094215963,
#   'drown': 0,
#   'à': 0,
#   'yeah': 0,
#   'road': 0,
#   'bang': 0,
#   'jesus': 2.995732273553991,
#   'insides': 0,
#   'burning': 0,
#   'stick': 0,
#   'signatures': 0,
#   'loss': 0,
#   'benji': 0,
#   'fall': 0,
#   'heart': 0,
#   'down': 0,
#   'things': 0,
#   'government': 0,
#   'need': 0,
#   'saint': 0,
#   'perfect': 0,
#   'dancing': 0,
#   'easy': 0,
#   'my': 1.7231316643698174,
#   'touch': 0,
#   'future': 0,
#   'homecoming': 0,
#   'psych': 0,
#   'but': 0,
#   'streets': 0,
#   'him': 0,
#   'multitudes': 0,
#   'montana': 0,
#   'rules': 0,
#   'culture': 0,
#   'fates': 0,
#   'wives': 0,
#   'whats': 0,
#   'cant': 0,
#   'fo': 0,
#   'kikiritikiki': 0,
#   'del': 0,
#   'raw': 0,
#   'drawn': 0,
#   'woo': 0,
#   'back': 0,
#   'spilled': 0,
#   'penthouse': 0,
#   'fly': 0,
#   'until': 0,
#   'nursin': 0,
#   'entitled': 0,
#   'prayer': 0,
#   'green': 2.302585092994046,
#   'lockjaw': 0,
#   'dealer': 0,
#   'dessert': 0,
#   'turn': 0,
#   'working': 0,
#   'bring': 0,
#   'lift': 0,
#   'see': 0,
#   'care': 0,
#   'spirit': 0,
#   'ends': 0,
#   'closed': 0,
#   'glock': 0,
#   'rebound': 0,
#   'way': 0,
#   'hop': 0,
#   'games': 0,
#   'found': 0,
#   'watch': 0,
#   'model': 0,
#   'talking': 0,
#   'committing': 0,
#   'murder': 0,
#   'best': 0,
#   'magnum': 0,
#   'hand': 0,
#   'standout': 0,
#   'conniving': 0,
#   'about': 1.2039728043259361,
#   'fears': 0,
#   'ah': 0,
#   'more': 0,
#   'night': 4.1588830833596715,
#   'petty': 0,
#   'their': 1.8971199848858813,
#   'mmm': 0,
#   'greater': 0,
#   'coming': 0,
#   'jukejoint': 0,
#   'rims': 0,
#   'victim': 0,
#   'front': 0,
#   'mama': 0,
#   'understand': 0,
#   'mass': 0,
#   'monday': 0,
#   'thinkin': 0,
#   'romantic': 0,
#   'from': 2.0794415416798357,
#   'wait': 0,
#   'makin': 0,
#   'lines': 0,
#   'neon': 0,
#   'asked': 0,
#   'moat': 0,
#   'benz': 0,
#   'known': 0,
#   'lick': 0,
#   'egotistic': 0,
#   'bite': 0,
#   'feeling': 0,
#   'hide': 0,
#   'breathe': 0,
#   'charter': 0,
#   'free': 5.691359954657644,
#   'corruption': 0,
#   'colours': 0,
#   'ceiling': 0,
#   'sees': 0,
#   'a': 0.8125946474888747,
#   'hey': 0,
#   'safe': 0,
#   'foggy': 0,
#   'playing': 0,
#   'ball': 0,
#   'wrongs': 0,
#   'bed': 2.995732273553991,
#   'workin': 0,
#   'tee': 0,
#   'millie': 0,
#   'trance': 0,
#   'turns': 0,
#   'sing': 0,
#   'mouth': 0,
#   'once': 0,
#   'fishing': 0,
#   'background': 0,
#   'walking': 0,
#   'hiding': 0,
#   'siena': 0,
#   'loud': 0,
#   'mines': 0,
#   'refined': 0,
#   'heading': 0,
#   'shooters': 0,
#   'stay': 0,
#   'sho': 0,
#   'kung-fu': 0,
#   'hurricanes': 0,
#   'youve': 0,
#   'get': 0,
#   'mapped': 0,
#   'loves': 0,
#   'too': 0,
#   'born': 6.907755278982138,
#   'litty': 0,
#   'settle': 0,
#   'quite': 0,
#   'she': 1.3862943611198906,
#   'freeze': 0,
#   'hurtin': 0,
#   'wrist': 0,
#   'feels': 0,
#   'wide': 0,
#   'it': 2.2314355131420975,
#   'stopping': 0,
#   'rhyme': 0,
#   'butter': 0,
#   'breakfast': 0,
#   'satisfied': 0,
#   'when': 0.3566749439387324,
#   'mercy': 0,
#   'jo-ann': 0,
#   'matches': 0,
#   'russians': 0,
#   'the': 3.9004543079465988,
#   'involved': 0,
#   'dealin': 0,
#   'drumming': 0,
#   'shes': 0,
#   'stealing': 0,
#   'sad': 2.995732273553991,
#   'blood': 0,
#   'emotion': 0,
#   'dark': 0,
#   'double': 0,
#   'comes': 0,
#   'glory': 0,
#   'flight': 0,
#   'behind': 0,
#   'plan': 0,
#   'savannah': 0,
#   'cryin': 0,
#   'vibrant': 0,
#   'ways': 0,
#   'church': 0,
#   'ate': 0,
#   'liney': 0,
#   'tapped': 0,
#   'bitch': 0,
#   'case': 0,
#   'emotional': 0,
#   'let': 0,
#   'sleight': 0,
#   'runnin': 4.1588830833596715,
#   'signed': 2.995732273553991,
#   'losin': 0,
#   'outside': 0,
#   'lit': 0,
#   'skip': 0,
#   'land': 0,
#   'can': 0,
#   'rode': 2.995732273553991,
#   'spit': 0,
#   'motion': 0,
#   'happened': 0,
#   'destruction': 0,
#   'congratulations': 0,
#   'color': 0,
#   'checks': 0,
#   'id': 0,
#   'ventura': 2.995732273553991,
#   'stand': 0,
#   'approach': 0,
#   'gang': 0,
#   'rocks': 0,
#   'youll': 0,
#   'forget': 2.302585092994046,
#   'armageddon': 0,
#   'vincent': 2.995732273553991,
#   'comfort': 0,
#   'track': 0,
#   'start': 0,
#   'racks': 0,
#   'skrrt': 0,
#   'everlasting': 0,
#   'forgot': 0,
#   'be': 0.43078291609245434,
#   'gentiles': 0,
#   'ego': 0,
#   'fuck': 0,
#   'expectations': 0,
#   'aching': 0,
#   'dropped': 0,
#   'gods': 8.987196820661973,
#   'kinda': 0,
#   'tears': 0,
#   'sunshine': 2.995732273553991,
#   'lady': 0,
#   'jamaica': 0,
#   'verbal': 0,
#   'falling': 0,
#   'c': 0,
#   'mirror': 0,
#   'earthquake': 0,
#   'fought': 0,
#   'ungdedele': 0,
#   'sorry': 0,
#   'flood': 0,
#   'sailing': 0,
#   'kind': 0,
#   'red': 1.8971199848858813,
#   'shows': 0,
#   'n': 0,
#   'zoom': 0,
#   'different': 0,
#   'singing': 0,
#   'left': 0,
#   'everywhere': 0,
#   'jackson': 0,
#   'all': 0.8925742052568391,
#   'days': 0,
#   'got': 0,
#   'prove': 0,
#   'piece': 0,
#   'fight': 0,
#   'kalashnikov': 0,
#   'ice': 0,
#   'cross': 2.995732273553991,
#   'planes': 0,
#   'cabanas': 0,
#   'law': 0,
#   'dust': 0,
#   'slob': 0,
#   'remedy': 0,
#   'submarine': 0,
#   'speed': 0,
#   'flowers': 0,
#   'siri': 0,
#   'syrup': 0,
#   'begins': 0,
#   '20': 0,
#   'adrenaline': 0,
#   'ask': 0,
#   'caution': 0,
#   'gettin': 0,
#   'grabs': 0,
#   'zone': 0,
#   'his-': 0,
#   'blades': 0,
#   'pride': 0,
#   'c4': 0,
#   'took': 4.605170185988092,
#   'window': 0,
#   'who': 0,
#   'desperate': 0,
#   'judge': 0,
#   'than': 0,
#   'bags': 0,
#   'body': 0,
#   'wearing': 0,
#   'hurts': 0,
#   'obscene': 0,
#   'walk': 0,
#   'disagreement': 0,
#   'should': 0,
#   'sure': 0,
#   'organized': 0,
#   'kings': 0,
#   'sword': 0,
#   'ohh': 0,
#   'door': 0,
#   'vienna': 0,
#   'crime': 0,
#   'moving': 0,
#   'indifferent': 0,
#   'hoping': 0,
#   'street': 0,
#   'guys': 0,
#   'they': 1.7935110022668612,
#   'rocking': 0,
#   '8teen': 32.9530550090939,
#   'confidence': 0,
#   'ménage': 0,
#   'shirt': 0,
#   'do': 0,
#   'glowin': 0,
#   'space': 0,
#   'sacrifice': 0,
#   'though': 2.302585092994046,
#   'plate': 2.302585092994046,
#   'before': 0,
#   'holding': 0,
#   'rhymes': 0,
#   'save': 0,
#   'pearly': 8.987196820661973,
#   'party': 0,
#   'momma': 0,
#   'never': 1.8325814637483102,
#   'sun': 0,
#   'baby': 0,
#   'lent': 2.995732273553991,
#   'bossed': 0,
#   'evening': 0,
#   'hummed': 2.995732273553991,
#   'underlined': 2.995732273553991,
#   'patois': 0,
#   'trois': 0,
#   'defeat': 0,
#   'raging': 0,
#   'late': 0,
#   'close': 0,
#   'going': 0,
#   'war': 0,
#   'counting': 0,
#   'week': 0,
#   'forever': 4.605170185988092,
#   'calculated': 0,
#   'dawg': 0,
#   'wanting': 0,
#   'find': 0,
#   'day': 2.0996442489973552,
#   'letter': 0,
#   'slow': 0,
#   'worked': 0,
#   'half': 0,
#   'tryin': 0,
#   'wine': 0,
#   'suit': 0,
#   'iggy': 0,
#   'clyde': 0,
#   'kill': 0,
#   'these': 0,
#   'keys': 0,
#   'and': 0.7693994158132572,
#   'hall': 0,
#   'armory': 0,
#   'secret': 0,
#   'air': 0,
#   'romance': 0,
#   'second': 0,
#   'fee': 0,
#   'pretty': 0,
#   'coupe': 0,
#   'smile': 0,
#   'pictures': 0,
#   'thats': 0,
#   'lane': 0,
#   'credit': 0,
#   'later': 0,
#   'told': 0,
#   'felt': 0,
#   'pulled': 0,
#   'hopin': 0,
#   'brain': 0,
#   'breathin': 0,
#   'beg': 0,
#   'shake': 0,
#   'girl': 1.2039728043259361,
#   'hed': 0,
#   'hope': 0,
#   'thanks': 0,
#   'sometimes': 0,
#   'hit': 0,
#   'said': 2.302585092994046,
#   'missing': 0,
#   'unwind': 0,
#   'system': 0,
#   'footprints': 0,
#   'white': 0,
#   'against': 0,
#   'open': 0,
#   'pumps': 0,
#   'control': 0,
#   'full': 0,
#   'tourist': 0,
#   'drummer': 0,
#   'shame': 0,
#   'bend': 0,
#   'meet': 0,
#   'realize': 0,
#   'whos': 0,
#   'ballistic': 0,
#   'crazy': 0,
#   'blessing': 8.987196820661973,
#   'say': 0,
#   'me': 0.44628710262841953,
#   'beneath': 2.302585092994046,
#   'complete': 0,
#   'snakin': 0,
#   'by': 0,
#   'honky-tonk': 0,
#   'shots': 0,
#   'aftermath': 0,
#   'antidote': 0,
#   'thought': 0,
#   'mind': 1.6094379124341003,
#   'shell': 0,
#   'souls': 0,
#   'desert': 0,
#   'try': 0,
#   'truth': 0,
#   'them': 0,
#   'uh': 0,
#   'to': 0.5642262382630553,
#   'blah': 0,
#   'subject': 0,
#   'maybe': 0,
#   'one': 0,
#   'rightful': 0,
#   'extensions': 0,
#   'channel': 0,
#   'attack': 0,
#   'shoulder': 0,
#   'enshrined': 2.995732273553991,
#   'go': 0,
#   'please': 0,
#   'operator': 0,
#   'hear': 0,
#   'always': 0,
#   'brother': 0,
#   'casualty': 0,
#   'clydes': 0,
#   'tendons': 0,
#   'better': 0,
#   'hero': 0,
#   'alive': 0,
#   'sign': 0,
#   'ones': 0,
#   'blindfolded': 0,
#   'youd': 0,
#   'only': 0,
#   'guess': 0,
#   'hes': 0,
#   'love': 0,
#   'sin': 0,
#   'member': 0,
#   'damn': 0,
#   'rain': 0,
#   'lil': 0,
#   'wouldnt': 0,
#   'chantin': 0,
#   'bet': 0,
#   'broads': 0,
#   'first': 0,
#   'compound': 0,
#   'same': 0,
#   'together': 2.302585092994046,
#   'problem': 0,
#   'phillipe': 0,
#   'juice': 0,
#   'ungbambe': 0,
#   'hol': 0,
#   'nothing': 0,
#   'give': 0,
#   'yaow': 0,
#   'everybody': 0,
#   'goes': 0,
#   'put': 0,
#   'kathleen': 0,
#   'pajamas': 0,
#   'ready': 0,
#   'false': 0,
#   'spinning': 0,
#   'lean': 0,
#   'needs': 0,
#   'kept': 2.302585092994046,
#   'luck': 8.987196820661973,
#   'driving': 0,
#   'good': 0,
#   'politics': 0,
#   'haunt': 0,
#   'wins': 0,
#   'else': 0,
#   'chill': 0,
#   'swaps': 0,
#   'coons': 0,
#   'beach': 0,
#   'thank': 0,
#   'triggering': 0,
#   'letters': 2.995732273553991,
#   'many': 0,
#   'kickin': 0,
#   'over': 0,
#   'covered': 0,
#   'champaign-urbana': 0,
#   'done': 0,
#   '9': 2.302585092994046,
#   'bullshit': 0,
#   'magnums': 0,
#   'blonde': 0,
#   'high': 0,
#   'beside': 2.995732273553991,
#   'stutter': 0,
#   'cleaver': 0,
#   'plus': 0,
#   'foreman': 0,
#   'genocide': 0,
#   'equal': 0,
#   'butterflies': 0,
#   'reside': 0,
#   'message': 0,
#   'somethings': 0,
#   'band': 0,
#   'just': 0,
#   'change': 0,
#   'buildin': 0,
#   'survive': 0,
#   'spent': 2.995732273553991,
#   'whole': 0,
#   'myself': 0,
#   'game': 0,
#   'like': 0,
#   'getting': 0,
#   'hot': 0,
#   'unleash': 0,
#   'fair': 0,
#   'chords': 0,
#   'sleep': 0,
#   'knees': 0,
#   'boat': 0,
#   'waited': 0,
#   'polite': 0,
#   'ya': 0,
#   'friends': 0,
#   'loving': 0,
#   'breaks': 0,
#   'at': 0,
#   'bleeding': 0,
#   'gift': 6.907755278982138,
#   'perimeter': 0,
#   'running': 0,
#   'amen': 0,
#   'castin': 0,
#   'flex': 0,
#   'alabama': 0,
#   'switch': 0,
#   'yall': 0,
#   'pow': 0,
#   'ground': 0,
#   'throw': 0,
#   'criminal': 0,
#   'subliminal': 0,
#   'did': 0,
#   'other': 0,
#   'hold': 1.6094379124341003,
#   'or': 5.545177444479562,
#   'us': 0,
#   'nobody': 0,
#   'knowing': 0,
#   'ima': 0,
#   'bought': 0,
#   'squad': 0,
#   'anywhere': 0,
#   'maple': 2.995732273553991,
#   'beams': 0,
#   'somebody': 0,
#   'claimed': 0,
#   'heard': 4.605170185988092,
#   'posters': 0,
#   'starts': 0,
#   'buddies': 0,
#   'people': 0,
#   'prophecy': 0,
#   'we': 3.4657359027997265,
#   'world': 0,
#   'dog': 0,
#   'flash': 0,
#   'onto': 0,
#   'making': 0,
#   'whip': 0,
#   'want': 0,
#   'wept': 0,
#   'pick-up': 0,
#   'answer': 0,
#   'scope': 0,
#   'knew': 0,
#   'asks': 0,
#   'here': 0,
#   'really': 0,
#   'swore': 0,
#   'small': 0,
#   'og': 0,
#   'slick': 0,
#   'do-do-do-do': 0,
#   'lives': 0,
#   'dreams': 1.8971199848858813,
#   'would': 0,
#   'falls': 0,
#   'pristine': 2.995732273553991,
#   'enough': 0,
#   'lungs': 0,
#   'may': 0,
#   'children': 0,
#   'hers': 0,
#   'somewhere': 0,
#   'stubborn': 0,
#   'shit': 0,
#   'title': 0,
#   'talk': 0,
#   'draw': 0,
#   'thieving': 0,
#   'pray': 0,
#   'haters': 0,
#   'lose': 0,
#   'now': 1.6094379124341003,
#   'trying': 0,
#   'top': 0,
#   'havent': 0,
#   'bust': 0,
#   'scared': 0,
#   'tend': 0,
#   'engine': 0,
#   'steppin': 0,
#   'money': 0,
#   'passage': 8.987196820661973,
#   'doin': 0,
#   'swingin': 0,
#   'its': 0,
#   'dinner': 0,
#   'times': 0,
#   'dance': 0,
#   'wake': 0,
#   'red-head': 0,
#   'forgotten': 0,
#   'seems': 0,
#   'much': 0,
#   'travel': 0,
#   'aimin': 0,
#   'know-ow': 0,
#   'rodeo': 2.995732273553991,
#   'motherfucker': 0,
#   'bag': 0,
#   'clean': 0,
#   'leaf': 2.995732273553991,
#   'target': 0,
#   'are': 0,
#   'bangs': 0,
#   'comin': 0,
#   'set': 0,
#   'our': 0,
#   'happy': 0,
#   'surface': 0,
#   'lawless': 0,
#   'herby': 0,
#   'remote': 0,
#   'master': 0,
#   'repeat': 0,
#   'jc': 2.995732273553991,
#   'diddy': 0,
#   'sacrificed': 0,
#   'move': 0,
#   'debt': 0,
#   'i': 0,
#   'status': 0,
#   'mayhem': 0,
#   'six': 2.995732273553991,
#   'knockoff': 0,
#   'nigga': 0,
#   'worse': 0,
#   'standby': 0,
#   'floor': 0,
#   'as': 1.2039728043259361,
#   'euphoria': 0,
#   'wrong': 0,
#   'unggudluke': 0,
#   'show': 0,
#   'to—': 0,
#   'rubber': 0,
#   'simply': 0,
#   'clique': 0,
#   'hazy': 0,
#   'sitting': 0,
#   'still': 0,
#   'city': 0,
#   'trees': 0,
#   'wild': 5.691359954657644,
#   'dont': 0,
#   'cocaine': 0,
#   'louisiana': 0,
#   'shoot': 0,
#   'moral': 0,
#   'bars': 0,
#   'make': 0,
#   'places': 0,
#   'niggas': 0,
#   'teach': 8.987196820661973,
#   'tangle': 0,
#   'bodys': 0,
#   "''": 0,
#   'side': 0,
#   'yous': 0,
#   'swimming': 0,
#   'today': 0,
#   'weaver': 0,
#   'out': 0.3566749439387324,
#   'low': 0,
#   'gates': 8.987196820661973,
#   'valentines': 2.995732273553991,
#   'loved': 0,
#   'big': 1.3862943611198906,
#   'swing': 0,
#   'know-ow-ow': 0,
#   'herb': 2.995732273553991,
#   'ropes': 0,
#   'off': 0,
#   'dead': 0,
#   'every': 2.772588722239781,
#   'boo': 0,
#   'reverence': 0,
#   'stack': 0,
#   'pedigree': 0,
#   'screaming': 0,
#   'em': 0,
#   'coast': 0,
#   'smoke': 0,
#   'radion': 0,
#   'words': 5.991464547107982,
#   'weekend': 0,
#   'after': 0,
#   'check': 0,
#   'mothafuck': 0,
#   'pack': 0,
#   'push': 0,
#   'meant': 0,
#   'sand': 0,
#   'blackin': 0,
#   'hours': 0,
#   'mopped': 0,
#   'sound': 0,
#   'size': 0,
#   'trinity': 8.987196820661973,
#   'die': 0,
#   'depending': 0,
#   'righteous': 0,
#   'doubt': 0,
#   '500': 0,
#   'electorial': 0,
#   'scarface': 0,
#   'roar': 0,
#   'relief': 0,
#   'emergency': 0,
#   'chitty': 0,
#   'whippin': 0,
#   'where': 1.6094379124341003,
#   'prowl': 0,
#   'confetti': 0,
#   'rest': 0,
#   'puddles': 0,
#   'dying': 0,
#   'killmonger': 0,
#   'phone': 0,
#   'car': 0,
#   'work': 0,
#   'am': 0,
#   'gone': 0,
#   'lasers': 0,
#   'zero': 0,
#   'probably': 0,
#   'sea': 8.987196820661973,
#   'straight': 0,
#   'ears': 0,
#   'new': 1.8971199848858813,
#   'swear': 0,
#   'clutchin': 0,
#   'drive': 0,
#   'hundred': 0,
#   'promised': 0,
#   'score': 0,
#   'long': 0,
#   'everyone': 6.907755278982138,
#   'everything': 0,
#   'endorsin': 0,
#   'fingerprints': 0,
#   'finally': 0,
#   'friday': 0,
#   'theres': 1.0498221244986776,
#   'cyborg': 0,
#   'warfare': 0,
#   'guyana': 0,
#   'such': 2.995732273553991,
#   'ralphs': 0,
#   'nothin': 0,
#   'is': 0,
#   'movin': 0,
#   'karaoke': 0,
#   'two': 0,
#   'paraplegic': 0,
#   'views': 0,
#   'miss': 0,
#   'knows': 0,
#   'four': 0,
#   'beast': 0,
#   'chase': 0,
#   'seen': 0,
#   'ta': 0,
#   'opps': 0,
#   'through': 3.1494663734960326,
#   'strings': 2.995732273553991,
#   'night-call': 0,
#   'ad-lib': 0,
#   'little': 0,
#   'those': 0,
#   'doorsteps': 0,
#   'sneak': 0,
#   'sundown': 0,
#   'country': 0,
#   'neighbor': 0,
#   'syrupd': 0,
#   'soon': 0,
#   'goin': 0,
#   'state': 2.995732273553991,
#   'last': 0,
#   'balance': 0,
#   'cowboys': 0,
#   'rollin': 0,
#   '87': 0,
#   'bypass': 0,
#   'stretch': 0,
#   'gosh': 0,
#   'god': 0,
#   'cause': 0,
#   'gas': 0,
#   'thirty': 0,
#   'ungbhasobhe': 0,
#   'sinister': 0,
#   'angel': 0,
#   'panther': 0,
#   'morgue': 0,
#   'look': 0,
#   'jumpin': 0,
#   'realest': 0,
#   'blind': 0,
#   'two-thirds': 0,
#   'wreck': 0,
#   'whoever': 0,
#   'important': 0,
#   'ocean': 0,
#   'center-attention': 0,
#   'japan': 2.995732273553991,
#   'home': 0,
#   'traffic': 0,
#   'machine': 0,
#   'indiana': 0,
#   'dial': 0,
#   'gets': 0,
#   'gave': 0,
#   'keep': 0,
#   'come': 0,
#   'had': 0,
#   'whoa': 0,
#   'name': 0,
#   'topped-off': 0,
#   'section': 0,
#   'figurines': 0,
#   'nerve': 0,
#   'that': 0.9751135769866497,
#   'what': 0,
#   'corrupt': 0,
#   'ship': 0,
#   'hoped': 0,
#   'needle': 0,
#   'girls': 0,
#   'well': 0,
#   'nightstand': 0,
#   'his': 1.8971199848858813,
#   'scenes': 2.995732273553991,
#   'theyre': 0,
#   'sky': 0,
#   'beam': 0,
#   'beat': 0,
#   'feelings': 0,
#   'opinion': 0,
#   'miracle': 2.995732273553991,
#   'building': 0,
#   'occurred': 2.995732273553991,
#   'brothers': 0,
#   'pull': 0,
#   'admission': 0,
#   'anything': 0,
#   'taxi': 0,
#   'pain': 0,
#   'even': 0,
#   'wan': 0,
#   'thinking': 0,
#   'thunder': 2.995732273553991,
#   'lights': 0,
#   'were': 0,
#   '83': 0,
#   'bullet': 2.302585092994046,
#   'crash': 0,
#   'integrity': 0,
#   'somethin': 0,
#   'cup': 8.987196820661973,
#   'rejoin': 0,
#   'pimp': 0,
#   'sands': 0,
#   'has': 0,
#   'changed': 0,
#   'eyy': 0,
#   'no': 0,
#   'away': 0,
#   'song': 2.302585092994046,
#   'passed': 2.995732273553991,
#   'this': 0,
#   'hollow': 0,
#   'word': 0,
#   '4': 0,
#   'your': 0,
#   'cars': 0,
#   'again': 0,
#   'stars': 0,
#   'woah': 0,
#   'laughing': 0,
#   'grindin': 0,
#   'belittles': 0,
#   'queen': 0,
#   'worth': 0,
#   'ear': 2.995732273553991,
#   'right': 0,
#   'circumstance': 0,
#   'havana': 0,
#   'fourteen': 2.995732273553991,
#   'must': 0,
#   'dirty': 0,
#   'friend': 0,
#   'guards': 0,
#   'lox': 0,
#   'walked': 2.995732273553991,
#   'hang': 0,
#   'whiskey': 0,
#   'blue': 0,
#   'runneth': 8.987196820661973,
#   'hard': 0,
#   'deaf': 0,
#   'faith': 0,
#   'showing': 0,
#   'another': 0,
#   'broken': 0,
#   'kitchen': 0,
#   'chess': 0,
#   'borderline': 2.995732273553991,
#   'jack': 0,
#   'absent': 0,
#   'armored': 0,
#   ...},
#  {'ever': 0,
#   'adds': 0,
#   'drown': 0,
#   'à': 0,
#   'yeah': 3.1494663734960326,
#   'road': 1.8971199848858813,
#   'bang': 0,
#   'jesus': 0,
#   'insides': 0,
#   'burning': 0,
#   'stick': 0,
#   'signatures': 0,
#   'loss': 0,
#   'benji': 0,
#   'fall': 0,
#   'heart': 0,
#   'down': 0,
#   'things': 0,
#   'government': 0,
#   'need': 0,
#   'saint': 0,
#   'perfect': 0,
#   'dancing': 0,
#   'easy': 0,
#   'my': 2.584697496554726,
#   'touch': 0,
#   'future': 0,
#   'homecoming': 0,
#   'psych': 0,
#   'but': 0,
#   'streets': 0,
#   'him': 0,
#   'multitudes': 0,
#   'montana': 0,
#   'rules': 0,
#   'culture': 0,
#   'fates': 0,
#   'wives': 0,
#   'whats': 0,
#   'cant': 0,
#   'fo': 0,
#   'kikiritikiki': 0,
#   'del': 0,
#   'raw': 0,
#   'drawn': 0,
#   'woo': 0,
#   'back': 1.2039728043259361,
#   'spilled': 0,
#   'penthouse': 0,
#   'fly': 0,
#   'until': 0,
#   'nursin': 0,
#   'entitled': 0,
#   'prayer': 0,
#   'green': 0,
#   'lockjaw': 0,
#   'dealer': 0,
#   'dessert': 0,
#   'turn': 0,
#   'working': 2.995732273553991,
#   'bring': 0,
#   'lift': 0,
#   'see': 0,
#   'care': 0,
#   'spirit': 0,
#   'ends': 6.907755278982138,
#   'closed': 0,
#   'glock': 0,
#   'rebound': 0,
#   'way': 4.8158912173037445,
#   'hop': 0,
#   'games': 0,
#   'found': 0,
#   'watch': 0,
#   'model': 0,
#   'talking': 2.995732273553991,
#   'committing': 0,
#   'murder': 0,
#   'best': 0,
#   'magnum': 0,
#   'hand': 0,
#   'standout': 0,
#   'conniving': 0,
#   'about': 0,
#   'fears': 0,
#   'ah': 0,
#   'more': 0,
#   'night': 0,
#   'petty': 0,
#   'their': 0,
#   'mmm': 0,
#   'greater': 0,
#   'coming': 0,
#   'jukejoint': 0,
#   'rims': 0,
#   'victim': 0,
#   'front': 0,
#   'mama': 0,
#   'understand': 0,
#   'mass': 0,
#   'monday': 0,
#   'thinkin': 0,
#   'romantic': 0,
#   'from': 0,
#   'wait': 1.8971199848858813,
#   'makin': 0,
#   'lines': 0,
#   'neon': 0,
#   'asked': 0,
#   'moat': 0,
#   'benz': 0,
#   'known': 0,
#   'lick': 0,
#   'egotistic': 0,
#   'bite': 0,
#   'feeling': 0,
#   'hide': 0,
#   'breathe': 0,
#   'charter': 0,
#   'free': 0,
#   'corruption': 0,
#   'colours': 0,
#   'ceiling': 0,
#   'sees': 0,
#   'a': 0.3250378589955499,
#   'hey': 0,
#   'safe': 0,
#   'foggy': 0,
#   'playing': 0,
#   'ball': 0,
#   'wrongs': 0,
#   'bed': 0,
#   'workin': 0,
#   'tee': 0,
#   'millie': 0,
#   'trance': 0,
#   'turns': 0,
#   'sing': 0,
#   'mouth': 0,
#   'once': 0,
#   'fishing': 0,
#   'background': 0,
#   'walking': 0,
#   'hiding': 0,
#   'siena': 0,
#   'loud': 0,
#   'mines': 0,
#   'refined': 0,
#   'heading': 0,
#   'shooters': 0,
#   'stay': 0,
#   'sho': 0,
#   'kung-fu': 0,
#   'hurricanes': 0,
#   'youve': 0,
#   'get': 0,
#   'mapped': 0,
#   'loves': 0,
#   'too': 0,
#   'born': 0,
#   'litty': 0,
#   'settle': 0,
#   'quite': 0,
#   'she': 0,
#   'freeze': 0,
#   'hurtin': 0,
#   'wrist': 0,
#   'feels': 0,
#   'wide': 0,
#   'it': 1.3388613078852587,
#   'stopping': 0,
#   'rhyme': 0,
#   'butter': 0,
#   'breakfast': 2.995732273553991,
#   'satisfied': 0,
#   'when': 0.7133498878774648,
#   'mercy': 0,
#   'jo-ann': 0,
#   'matches': 0,
#   'russians': 0,
#   'the': 1.6251892949777493,
#   'involved': 0,
#   'dealin': 0,
#   'drumming': 0,
#   'shes': 1.8971199848858813,
#   'stealing': 0,
#   'sad': 0,
#   'blood': 0,
#   'emotion': 0,
#   'dark': 0,
#   'double': 0,
#   'comes': 0,
#   'glory': 0,
#   'flight': 0,
#   'behind': 0,
#   'plan': 0,
#   'savannah': 0,
#   'cryin': 0,
#   'vibrant': 0,
#   'ways': 0,
#   'church': 0,
#   'ate': 0,
#   'liney': 0,
#   'tapped': 0,
#   'bitch': 0,
#   'case': 0,
#   'emotional': 0,
#   'let': 0,
#   'sleight': 0,
#   'runnin': 0,
#   'signed': 0,
#   'losin': 0,
#   'outside': 0,
#   'lit': 0,
#   'skip': 0,
#   'land': 0,
#   'can': 0,
#   'rode': 0,
#   'spit': 0,
#   'motion': 0,
#   'happened': 0,
#   'destruction': 0,
#   'congratulations': 0,
#   'color': 0,
#   'checks': 0,
#   'id': 0,
#   'ventura': 0,
#   'stand': 0,
#   'approach': 0,
#   'gang': 0,
#   'rocks': 0,
#   'youll': 0,
#   'forget': 0,
#   'armageddon': 0,
#   'vincent': 0,
#   'comfort': 0,
#   'track': 0,
#   'start': 0,
#   'racks': 0,
#   'skrrt': 0,
#   'everlasting': 0,
#   'forgot': 0,
#   'be': 1.292348748277363,
#   'gentiles': 0,
#   'ego': 0,
#   'fuck': 0,
#   'expectations': 0,
#   'aching': 2.995732273553991,
#   'dropped': 0,
#   'gods': 0,
#   'kinda': 0,
#   'tears': 0,
#   'sunshine': 0,
#   'lady': 0,
#   'jamaica': 0,
#   'verbal': 0,
#   'falling': 0,
#   'c': 0,
#   'mirror': 0,
#   'earthquake': 0,
#   'fought': 0,
#   'ungdedele': 0,
#   'sorry': 0,
#   'flood': 0,
#   'sailing': 0,
#   'kind': 0,
#   'red': 0,
#   'shows': 0,
#   'n': 0,
#   'zoom': 0,
#   'different': 0,
#   'singing': 0,
#   'left': 0,
#   'everywhere': 0,
#   'jackson': 0,
#   'all': 0.8925742052568391,
#   'days': 0,
#   'got': 0,
#   'prove': 0,
#   'piece': 0,
#   'fight': 0,
#   'kalashnikov': 0,
#   'ice': 0,
#   'cross': 0,
#   'planes': 0,
#   'cabanas': 0,
#   'law': 0,
#   'dust': 0,
#   'slob': 0,
#   'remedy': 0,
#   'submarine': 0,
#   'speed': 0,
#   'flowers': 0,
#   'siri': 0,
#   'syrup': 0,
#   'begins': 6.907755278982138,
#   '20': 0,
#   'adrenaline': 0,
#   'ask': 0,
#   'caution': 0,
#   'gettin': 0,
#   'grabs': 0,
#   'zone': 0,
#   'his-': 0,
#   'blades': 0,
#   'pride': 0,
#   'c4': 0,
#   'took': 0,
#   'window': 0,
#   'who': 0.7985076962177716,
#   'desperate': 0,
#   'judge': 0,
#   'than': 0,
#   'bags': 0,
#   'body': 0,
#   'wearing': 2.995732273553991,
#   'hurts': 0,
#   'obscene': 0,
#   'walk': 0,
#   'disagreement': 0,
#   'should': 3.7942399697717626,
#   'sure': 0,
#   'organized': 0,
#   'kings': 0,
#   'sword': 0,
#   'ohh': 0,
#   'door': 0,
#   'vienna': 0,
#   'crime': 0,
#   'moving': 0,
#   'indifferent': 0,
#   'hoping': 0,
#   'street': 0,
#   'guys': 0,
#   'they': 0.5978370007556204,
#   'rocking': 0,
#   '8teen': 0,
#   'confidence': 0,
#   'ménage': 0,
#   'shirt': 2.995732273553991,
#   'do': 0,
#   'glowin': 0,
#   'space': 0,
#   'sacrifice': 0,
#   'though': 0,
#   'plate': 0,
#   'before': 0,
#   'holding': 0,
#   'rhymes': 0,
#   'save': 0,
#   'pearly': 0,
#   'party': 5.691359954657644,
#   'momma': 0,
#   'never': 1.8325814637483102,
#   'sun': 0,
#   'baby': 0,
#   'lent': 0,
#   'bossed': 0,
#   'evening': 0,
#   'hummed': 0,
#   'underlined': 0,
#   'patois': 0,
#   'trois': 0,
#   'defeat': 0,
#   'raging': 0,
#   'late': 5.991464547107982,
#   'close': 0,
#   'going': 1.6094379124341003,
#   'war': 0,
#   'counting': 0,
#   'week': 0,
#   'forever': 0,
#   'calculated': 0,
#   'dawg': 0,
#   'wanting': 2.995732273553991,
#   'find': 0,
#   'day': 0,
#   'letter': 0,
#   'slow': 0,
#   'worked': 0,
#   'half': 0,
#   'tryin': 0,
#   'wine': 0,
#   'suit': 0,
#   'iggy': 0,
#   'clyde': 0,
#   'kill': 0,
#   'these': 0,
#   'keys': 0,
#   'and': 0.41034635510040385,
#   'hall': 0,
#   'armory': 0,
#   'secret': 0,
#   'air': 0,
#   'romance': 0,
#   'second': 0,
#   'fee': 0,
#   'pretty': 0,
#   'coupe': 0,
#   'smile': 0,
#   'pictures': 0,
#   'thats': 4.1588830833596715,
#   'lane': 2.995732273553991,
#   'credit': 0,
#   'later': 0,
#   'told': 0,
#   'felt': 0,
#   'pulled': 0,
#   'hopin': 0,
#   'brain': 0,
#   'breathin': 0,
#   'beg': 0,
#   'shake': 0,
#   'girl': 1.2039728043259361,
#   'hed': 0,
#   'hope': 0,
#   'thanks': 0,
#   'sometimes': 0,
#   'hit': 0,
#   'said': 0,
#   'missing': 0,
#   'unwind': 0,
#   'system': 0,
#   'footprints': 0,
#   'white': 0,
#   'against': 0,
#   'open': 0,
#   'pumps': 0,
#   'control': 0,
#   'full': 0,
#   'tourist': 0,
#   'drummer': 0,
#   'shame': 0,
#   'bend': 0,
#   'meet': 0,
#   'realize': 0,
#   'whos': 0,
#   'ballistic': 0,
#   'crazy': 0,
#   'blessing': 0,
#   'say': 1.0498221244986776,
#   'me': 0.22314355131420976,
#   'beneath': 0,
#   'complete': 0,
#   'snakin': 0,
#   'by': 0,
#   'honky-tonk': 0,
#   'shots': 0,
#   'aftermath': 0,
#   'antidote': 0,
#   'thought': 0,
#   'mind': 0,
#   'shell': 0,
#   'souls': 0,
#   'desert': 0,
#   'try': 0,
#   'truth': 0,
#   'them': 0,
#   'uh': 0,
#   'to': 0.10258658877510096,
#   'blah': 0,
#   'subject': 0,
#   'maybe': 0,
#   'one': 0,
#   'rightful': 0,
#   'extensions': 0,
#   'channel': 0,
#   'attack': 0,
#   'shoulder': 0,
#   'enshrined': 0,
#   'go': 0,
#   'please': 0,
#   'operator': 0,
#   'hear': 0,
#   'always': 0,
#   'brother': 0,
#   'casualty': 0,
#   'clydes': 0,
#   'tendons': 0,
#   'better': 0,
#   'hero': 0,
#   'alive': 0,
#   'sign': 0,
#   'ones': 0,
#   'blindfolded': 0,
#   'youd': 0,
#   'only': 0,
#   'guess': 2.995732273553991,
#   'hes': 0,
#   'love': 0,
#   'sin': 0,
#   'member': 0,
#   'damn': 0,
#   'rain': 0,
#   'lil': 0,
#   'wouldnt': 0,
#   'chantin': 0,
#   'bet': 0,
#   'broads': 0,
#   'first': 0,
#   'compound': 0,
#   'same': 0,
#   'together': 0,
#   'problem': 0,
#   'phillipe': 0,
#   'juice': 0,
#   'ungbambe': 0,
#   'hol': 0,
#   'nothing': 0,
#   'give': 0,
#   'yaow': 0,
#   'everybody': 0,
#   'goes': 5.991464547107982,
#   'put': 0,
#   'kathleen': 0,
#   'pajamas': 0,
#   'ready': 0,
#   'false': 0,
#   'spinning': 0,
#   'lean': 0,
#   'needs': 0,
#   'kept': 0,
#   'luck': 0,
#   'driving': 0,
#   'good': 0,
#   'politics': 0,
#   'haunt': 0,
#   'wins': 0,
#   'else': 0,
#   'chill': 0,
#   'swaps': 0,
#   'coons': 0,
#   'beach': 0,
#   'thank': 0,
#   'triggering': 0,
#   'letters': 0,
#   'many': 0,
#   'kickin': 0,
#   'over': 2.772588722239781,
#   'covered': 0,
#   'champaign-urbana': 0,
#   'done': 0,
#   '9': 0,
#   'bullshit': 0,
#   'magnums': 0,
#   'blonde': 0,
#   'high': 0,
#   'beside': 0,
#   'stutter': 0,
#   'cleaver': 0,
#   'plus': 0,
#   'foreman': 2.995732273553991,
#   'genocide': 0,
#   'equal': 0,
#   'butterflies': 0,
#   'reside': 0,
#   'message': 0,
#   'somethings': 0,
#   'band': 0,
#   'just': 0.8615658321849087,
#   'change': 0,
#   'buildin': 0,
#   'survive': 0,
#   'spent': 0,
#   'whole': 0,
#   'myself': 0,
#   'game': 0,
#   'like': 0,
#   'getting': 0,
#   'hot': 0,
#   'unleash': 0,
#   'fair': 0,
#   'chords': 0,
#   'sleep': 2.302585092994046,
#   'knees': 0,
#   'boat': 0,
#   'waited': 0,
#   'polite': 0,
#   'ya': 0,
#   'friends': 8.047189562170502,
#   'loving': 0,
#   'breaks': 0,
#   'at': 0,
#   'bleeding': 0,
#   'gift': 0,
#   'perimeter': 0,
#   'running': 0,
#   'amen': 0,
#   'castin': 0,
#   'flex': 0,
#   'alabama': 0,
#   'switch': 0,
#   'yall': 0,
#   'pow': 0,
#   'ground': 0,
#   'throw': 0,
#   'criminal': 0,
#   'subliminal': 0,
#   'did': 0,
#   'other': 0,
#   'hold': 0,
#   'or': 0,
#   'us': 0,
#   'nobody': 0,
#   'knowing': 0,
#   'ima': 0,
#   'bought': 0,
#   'squad': 0,
#   'anywhere': 0,
#   'maple': 0,
#   'beams': 0,
#   'somebody': 0,
#   'claimed': 0,
#   'heard': 0,
#   'posters': 0,
#   'starts': 4.605170185988092,
#   'buddies': 5.991464547107982,
#   'people': 0,
#   'prophecy': 0,
#   'we': 0,
#   'world': 0,
#   'dog': 0,
#   'flash': 0,
#   'onto': 0,
#   'making': 0,
#   'whip': 0,
#   'want': 0,
#   'wept': 0,
#   'pick-up': 0,
#   'answer': 0,
#   'scope': 0,
#   'knew': 0,
#   'asks': 0,
#   'here': 0,
#   'really': 0,
#   'swore': 0,
#   'small': 0,
#   'og': 0,
#   'slick': 0,
#   'do-do-do-do': 0,
#   'lives': 0,
#   'dreams': 0,
#   'would': 0,
#   'falls': 0,
#   'pristine': 0,
#   'enough': 0,
#   'lungs': 0,
#   'may': 0,
#   'children': 0,
#   'hers': 0,
#   'somewhere': 0,
#   'stubborn': 0,
#   'shit': 0,
#   'title': 0,
#   'talk': 0,
#   'draw': 0,
#   'thieving': 0,
#   'pray': 0,
#   'haters': 0,
#   'lose': 0,
#   'now': 0,
#   'trying': 0,
#   'top': 0,
#   'havent': 0,
#   'bust': 0,
#   'scared': 0,
#   'tend': 0,
#   'engine': 0,
#   'steppin': 0,
#   'money': 0,
#   'passage': 0,
#   'doin': 0,
#   'swingin': 0,
#   'its': 2.1539145804622715,
#   'dinner': 0,
#   'times': 0,
#   'dance': 0,
#   'wake': 0,
#   'red-head': 0,
#   'forgotten': 0,
#   'seems': 0,
#   'much': 0,
#   'travel': 0,
#   'aimin': 0,
#   'know-ow': 0,
#   'rodeo': 0,
#   'motherfucker': 0,
#   'bag': 0,
#   'clean': 0,
#   'leaf': 0,
#   'target': 0,
#   'are': 1.0498221244986776,
#   'bangs': 0,
#   'comin': 0,
#   'set': 0,
#   'our': 0,
#   'happy': 0,
#   'surface': 0,
#   'lawless': 0,
#   'herby': 0,
#   'remote': 0,
#   'master': 0,
#   'repeat': 0,
#   'jc': 0,
#   'diddy': 0,
#   'sacrificed': 0,
#   'move': 0,
#   'debt': 0,
#   'i': 0,
#   'status': 0,
#   'mayhem': 0,
#   'six': 0,
#   'knockoff': 0,
#   'nigga': 0,
#   'worse': 0,
#   'standby': 0,
#   'floor': 0,
#   'as': 4.8158912173037445,
#   'euphoria': 0,
#   'wrong': 0,
#   'unggudluke': 0,
#   'show': 0,
#   'to—': 0,
#   'rubber': 0,
#   'simply': 0,
#   'clique': 0,
#   'hazy': 0,
#   'sitting': 0,
#   'still': 0,
#   'city': 0,
#   'trees': 0,
#   'wild': 0,
#   'dont': 0,
#   'cocaine': 0,
#   'louisiana': 0,
#   'shoot': 0,
#   'moral': 0,
#   'bars': 0,
#   'make': 0,
#   'places': 0,
#   'niggas': 0,
#   'teach': 0,
#   'tangle': 0,
#   'bodys': 0,
#   "''": 0,
#   'side': 0,
#   'yous': 0,
#   'swimming': 0,
#   'today': 0,
#   'weaver': 0,
#   'out': 0.3566749439387324,
#   'low': 0,
#   'gates': 0,
#   'valentines': 0,
#   'loved': 0,
#   'big': 0,
#   'swing': 0,
#   'know-ow-ow': 0,
#   'herb': 0,
#   'ropes': 0,
#   'off': 0,
#   'dead': 0,
#   'every': 0,
#   'boo': 0,
#   'reverence': 0,
#   'stack': 0,
#   'pedigree': 0,
#   'screaming': 0,
#   'em': 0,
#   'coast': 0,
#   'smoke': 0,
#   'radion': 0,
#   'words': 0,
#   'weekend': 0,
#   'after': 0,
#   'check': 0,
#   'mothafuck': 0,
#   'pack': 0,
#   'push': 0,
#   'meant': 0,
#   'sand': 0,
#   'blackin': 0,
#   'hours': 0,
#   'mopped': 0,
#   'sound': 0,
#   'size': 0,
#   'trinity': 0,
#   'die': 0,
#   'depending': 0,
#   'righteous': 0,
#   'doubt': 0,
#   '500': 0,
#   'electorial': 0,
#   'scarface': 0,
#   'roar': 0,
#   'relief': 0,
#   'emergency': 0,
#   'chitty': 0,
#   'whippin': 0,
#   'where': 1.6094379124341003,
#   'prowl': 0,
#   'confetti': 0,
#   'rest': 0,
#   'puddles': 0,
#   'dying': 0,
#   'killmonger': 0,
#   'phone': 0,
#   'car': 0,
#   'work': 2.302585092994046,
#   'am': 0,
#   'gone': 0,
#   'lasers': 0,
#   'zero': 0,
#   'probably': 0,
#   'sea': 0,
#   'straight': 0,
#   'ears': 0,
#   'new': 0,
#   'swear': 0,
#   'clutchin': 0,
#   'drive': 0,
#   'hundred': 0,
#   'promised': 0,
#   'score': 0,
#   'long': 0,
#   'everyone': 0,
#   'everything': 0,
#   'endorsin': 0,
#   'fingerprints': 0,
#   'finally': 0,
#   'friday': 0,
#   'theres': 1.0498221244986776,
#   'cyborg': 0,
#   'warfare': 0,
#   'guyana': 0,
#   'such': 0,
#   'ralphs': 0,
#   'nothin': 0,
#   'is': 0.22314355131420976,
#   'movin': 0,
#   'karaoke': 0,
#   'two': 1.3862943611198906,
#   'paraplegic': 0,
#   'views': 0,
#   'miss': 0,
#   'knows': 0,
#   'four': 0,
#   'beast': 0,
#   'chase': 0,
#   'seen': 0,
#   'ta': 0,
#   'opps': 0,
#   'through': 0,
#   'strings': 0,
#   'night-call': 0,
#   'ad-lib': 0,
#   'little': 0,
#   'those': 0,
#   'doorsteps': 0,
#   'sneak': 0,
#   'sundown': 0,
#   'country': 0,
#   'neighbor': 0,
#   'syrupd': 0,
#   'soon': 5.991464547107982,
#   'goin': 0,
#   'state': 0,
#   'last': 0,
#   'balance': 0,
#   'cowboys': 14.978661367769954,
#   'rollin': 0,
#   '87': 0,
#   'bypass': 0,
#   'stretch': 0,
#   'gosh': 0,
#   'god': 0,
#   'cause': 2.772588722239781,
#   'gas': 0,
#   'thirty': 0,
#   'ungbhasobhe': 0,
#   'sinister': 0,
#   'angel': 0,
#   'panther': 0,
#   'morgue': 0,
#   'look': 0,
#   'jumpin': 0,
#   'realest': 0,
#   'blind': 0,
#   'two-thirds': 0,
#   'wreck': 0,
#   'whoever': 0,
#   'important': 0,
#   'ocean': 0,
#   'center-attention': 0,
#   'japan': 0,
#   'home': 1.8971199848858813,
#   'traffic': 0,
#   'machine': 0,
#   'indiana': 0,
#   'dial': 0,
#   'gets': 0,
#   'gave': 0,
#   'keep': 1.3862943611198906,
#   'come': 0,
#   'had': 0,
#   'whoa': 0,
#   'name': 0,
#   'topped-off': 0,
#   'section': 0,
#   'figurines': 0,
#   'nerve': 0,
#   'that': 1.1376325064844246,
#   'what': 0,
#   'corrupt': 0,
#   'ship': 0,
#   'hoped': 0,
#   'needle': 0,
#   'girls': 0,
#   'well': 0,
#   'nightstand': 2.995732273553991,
#   'his': 0,
#   'scenes': 0,
#   'theyre': 1.6094379124341003,
#   'sky': 0,
#   'beam': 0,
#   'beat': 0,
#   'feelings': 0,
#   'opinion': 0,
#   'miracle': 0,
#   'building': 0,
#   'occurred': 0,
#   'brothers': 0,
#   'pull': 0,
#   'admission': 0,
#   'anything': 0,
#   'taxi': 0,
#   'pain': 0,
#   'even': 0,
#   'wan': 0,
#   'thinking': 0,
#   'thunder': 0,
#   'lights': 0,
#   'were': 1.3862943611198906,
#   '83': 0,
#   'bullet': 0,
#   'crash': 0,
#   'integrity': 0,
#   'somethin': 0,
#   'cup': 0,
#   'rejoin': 0,
#   'pimp': 0,
#   'sands': 0,
#   'has': 0,
#   'changed': 0,
#   'eyy': 0,
#   'no': 0,
#   'away': 0,
#   'song': 0,
#   'passed': 0,
#   'this': 0.43078291609245434,
#   'hollow': 0,
#   'word': 0,
#   '4': 0,
#   'your': 0,
#   'cars': 0,
#   'again': 4.828313737302301,
#   'stars': 0,
#   'woah': 0,
#   'laughing': 0,
#   'grindin': 0,
#   'belittles': 0,
#   'queen': 0,
#   'worth': 0,
#   'ear': 0,
#   'right': 0,
#   'circumstance': 0,
#   'havana': 0,
#   'fourteen': 0,
#   'must': 0,
#   'dirty': 0,
#   'friend': 0,
#   'guards': 0,
#   'lox': 0,
#   'walked': 0,
#   'hang': 0,
#   'whiskey': 0,
#   'blue': 0,
#   'runneth': 0,
#   'hard': 0,
#   'deaf': 0,
#   'faith': 0,
#   'showing': 0,
#   'another': 0,
#   'broken': 0,
#   'kitchen': 2.995732273553991,
#   'chess': 0,
#   'borderline': 0,
#   'jack': 2.302585092994046,
#   'absent': 0,
#   'armored': 0,
#   ...},
#  {'ever': 0,
#   'adds': 0,
#   'drown': 0,
#   'à': 0,
#   'yeah': 0,
#   'road': 0,
#   'bang': 117.43183974269634,
#   'jesus': 0,
#   'insides': 0,
#   'burning': 0,
#   'stick': 0,
#   'signatures': 0,
#   'loss': 0,
#   'benji': 0,
#   'fall': 0,
#   'heart': 0,
#   'down': 1.0216512475319814,
#   'things': 0,
#   'government': 0,
#   'need': 0.9162907318741551,
#   'saint': 0,
#   'perfect': 2.995732273553991,
#   'dancing': 0,
#   'easy': 0,
#   'my': 0,
#   'touch': 0,
#   'future': 0,
#   'homecoming': 0,
#   'psych': 0,
#   'but': 1.0700248318161971,
#   'streets': 0,
#   'him': 9.210340371976184,
#   'multitudes': 0,
#   'montana': 0,
#   'rules': 0,
#   'culture': 0,
#   'fates': 0,
#   'wives': 0,
#   'whats': 0,
#   'cant': 0,
#   'fo': 0,
#   'kikiritikiki': 0,
#   'del': 0,
#   'raw': 0,
#   'drawn': 0,
#   'woo': 0,
#   'back': 0,
#   'spilled': 0,
#   'penthouse': 0,
#   'fly': 0,
#   'until': 0,
#   'nursin': 0,
#   'entitled': 0,
#   'prayer': 0,
#   'green': 0,
#   'lockjaw': 0,
#   'dealer': 2.995732273553991,
#   'dessert': 2.995732273553991,
#   'turn': 0,
#   'working': 0,
#   'bring': 0,
#   'lift': 0,
#   'see': 0.6931471805599453,
#   'care': 0,
#   'spirit': 0,
#   'ends': 0,
#   'closed': 0,
#   'glock': 0,
#   'rebound': 0,
#   'way': 0,
#   'hop': 0,
#   'games': 0,
#   'found': 0,
#   'watch': 0,
#   'model': 0,
#   'talking': 0,
#   'committing': 0,
#   'murder': 0,
#   'best': 0,
#   'magnum': 0,
#   'hand': 2.302585092994046,
#   'standout': 0,
#   'conniving': 2.995732273553991,
#   'about': 0,
#   'fears': 0,
#   'ah': 0,
#   'more': 1.6094379124341003,
#   'night': 0,
#   'petty': 2.995732273553991,
#   'their': 7.588479939543525,
#   'mmm': 0,
#   'greater': 0,
#   'coming': 0,
#   'jukejoint': 0,
#   'rims': 0,
#   'victim': 0,
#   'front': 0,
#   'mama': 0,
#   'understand': 0,
#   'mass': 0,
#   'monday': 2.995732273553991,
#   'thinkin': 0,
#   'romantic': 0,
#   'from': 0.6931471805599453,
#   'wait': 0,
#   'makin': 0,
#   'lines': 0,
#   'neon': 0,
#   'asked': 0,
#   'moat': 0,
#   'benz': 0,
#   'known': 0,
#   'lick': 0,
#   'egotistic': 0,
#   'bite': 0,
#   'feeling': 1.6094379124341003,
#   'hide': 0,
#   'breathe': 0,
#   'charter': 0,
#   'free': 0,
#   'corruption': 0,
#   'colours': 0,
#   'ceiling': 0,
#   'sees': 2.302585092994046,
#   'a': 0.8125946474888747,
#   'hey': 0,
#   'safe': 0,
#   'foggy': 0,
#   'playing': 0,
#   'ball': 0,
#   'wrongs': 0,
#   'bed': 0,
#   'workin': 0,
#   'tee': 0,
#   'millie': 0,
#   'trance': 0,
#   'turns': 5.991464547107982,
#   'sing': 0,
#   'mouth': 0,
#   'once': 2.995732273553991,
#   'fishing': 0,
#   'background': 0,
#   'walking': 0,
#   'hiding': 2.995732273553991,
#   'siena': 0,
#   'loud': 0,
#   'mines': 0,
#   'refined': 0,
#   'heading': 2.995732273553991,
#   'shooters': 0,
#   'stay': 0,
#   'sho': 0,
#   'kung-fu': 0,
#   'hurricanes': 0,
#   'youve': 0,
#   'get': 1.3862943611198906,
#   'mapped': 0,
#   'loves': 0,
#   'too': 0,
#   'born': 0,
#   'litty': 0,
#   'settle': 0,
#   'quite': 0,
#   'she': 11.090354888959125,
#   'freeze': 0,
#   'hurtin': 0,
#   'wrist': 0,
#   'feels': 0,
#   'wide': 0,
#   'it': 0.6694306539426294,
#   'stopping': 2.995732273553991,
#   'rhyme': 0,
#   'butter': 0,
#   'breakfast': 0,
#   'satisfied': 0,
#   'when': 1.0700248318161971,
#   'mercy': 0,
#   'jo-ann': 5.991464547107982,
#   'matches': 0,
#   'russians': 0,
#   'the': 3.9004543079465988,
#   'involved': 0,
#   'dealin': 0,
#   'drumming': 0,
#   'shes': 0,
#   'stealing': 0,
#   'sad': 0,
#   'blood': 0,
#   'emotion': 0,
#   'dark': 0,
#   'double': 0,
#   'comes': 0,
#   'glory': 0,
#   'flight': 0,
#   'behind': 0,
#   'plan': 2.302585092994046,
#   'savannah': 0,
#   'cryin': 0,
#   'vibrant': 0,
#   'ways': 1.6094379124341003,
#   'church': 0,
#   'ate': 0,
#   'liney': 0,
#   'tapped': 0,
#   'bitch': 0,
#   'case': 0,
#   'emotional': 0,
#   'let': 1.3862943611198906,
#   'sleight': 2.995732273553991,
#   'runnin': 0,
#   'signed': 0,
#   'losin': 0,
#   'outside': 0,
#   'lit': 0,
#   'skip': 0,
#   'land': 0,
#   'can': 0,
#   'rode': 0,
#   'spit': 0,
#   'motion': 0,
#   'happened': 2.995732273553991,
#   'destruction': 0,
#   'congratulations': 0,
#   'color': 0,
#   'checks': 0,
#   'id': 0,
#   'ventura': 0,
#   'stand': 0,
#   'approach': 0,
#   'gang': 0,
#   'rocks': 0,
#   'youll': 0,
#   'forget': 0,
#   'armageddon': 0,
#   'vincent': 0,
#   'comfort': 0,
#   'track': 0,
#   'start': 0,
#   'racks': 0,
#   'skrrt': 0,
#   'everlasting': 0,
#   'forgot': 0,
#   'be': 0,
#   'gentiles': 0,
#   'ego': 0,
#   'fuck': 0,
#   'expectations': 0,
#   'aching': 0,
#   'dropped': 0,
#   'gods': 0,
#   'kinda': 0,
#   'tears': 0,
#   'sunshine': 0,
#   'lady': 0,
#   'jamaica': 0,
#   'verbal': 0,
#   'falling': 0,
#   'c': 0,
#   'mirror': 0,
#   'earthquake': 0,
#   'fought': 0,
#   'ungdedele': 0,
#   'sorry': 0,
#   'flood': 0,
#   'sailing': 0,
#   'kind': 0,
#   'red': 0,
#   'shows': 2.995732273553991,
#   'n': 0,
#   'zoom': 0,
#   'different': 0,
#   'singing': 0,
#   'left': 0,
#   'everywhere': 0,
#   'jackson': 0,
#   'all': 0.22314355131420976,
#   'days': 0,
#   'got': 0,
#   'prove': 0,
#   'piece': 0,
#   'fight': 0,
#   'kalashnikov': 0,
#   'ice': 0,
#   'cross': 0,
#   'planes': 0,
#   'cabanas': 0,
#   'law': 0,
#   'dust': 0,
#   'slob': 0,
#   'remedy': 0,
#   'submarine': 0,
#   'speed': 0,
#   'flowers': 0,
#   'siri': 0,
#   'syrup': 0,
#   'begins': 4.605170185988092,
#   '20': 0,
#   'adrenaline': 0,
#   'ask': 0,
#   'caution': 0,
#   'gettin': 0,
#   'grabs': 2.995732273553991,
#   'zone': 0,
#   'his-': 0,
#   'blades': 0,
#   'pride': 0,
#   'c4': 0,
#   'took': 0,
#   'window': 2.995732273553991,
#   'who': 0.7985076962177716,
#   'desperate': 0,
#   'judge': 0,
#   'than': 0,
#   'bags': 5.991464547107982,
#   'body': 0,
#   'wearing': 0,
#   'hurts': 0,
#   'obscene': 0,
#   'walk': 0,
#   'disagreement': 0,
#   'should': 0,
#   'sure': 0,
#   'organized': 0,
#   'kings': 0,
#   'sword': 0,
#   'ohh': 0,
#   'door': 8.987196820661973,
#   'vienna': 0,
#   'crime': 2.995732273553991,
#   'moving': 0,
#   'indifferent': 0,
#   'hoping': 0,
#   'street': 0,
#   'guys': 0,
#   'they': 2.3913480030224816,
#   'rocking': 0,
#   '8teen': 0,
#   'confidence': 0,
#   'ménage': 0,
#   'shirt': 0,
#   'do': 0,
#   'glowin': 0,
#   'space': 0,
#   'sacrifice': 0,
#   'though': 0,
#   'plate': 0,
#   'before': 2.302585092994046,
#   'holding': 0,
#   'rhymes': 0,
#   'save': 0,
#   'pearly': 0,
#   'party': 0,
#   'momma': 0,
#   'never': 1.8325814637483102,
#   'sun': 0,
#   'baby': 0,
#   'lent': 0,
#   'bossed': 0,
#   'evening': 2.995732273553991,
#   'hummed': 0,
#   'underlined': 0,
#   'patois': 0,
#   'trois': 0,
#   'defeat': 0,
#   'raging': 0,
#   'late': 0,
#   'close': 0,
#   'going': 0,
#   'war': 0,
#   'counting': 0,
#   'week': 0,
#   'forever': 0,
#   'calculated': 0,
#   'dawg': 0,
#   'wanting': 0,
#   'find': 1.6094379124341003,
#   'day': 0,
#   'letter': 0,
#   'slow': 0,
#   'worked': 2.995732273553991,
#   'half': 0,
#   'tryin': 0,
#   'wine': 0,
#   'suit': 0,
#   'iggy': 0,
#   'clyde': 5.991464547107982,
#   'kill': 0,
#   'these': 0,
#   'keys': 0,
#   'and': 0.5642262382630553,
#   'hall': 0,
#   'armory': 0,
#   'secret': 0,
#   'air': 0,
#   'romance': 0,
#   'second': 0,
#   'fee': 0,
#   'pretty': 0,
#   'coupe': 0,
#   'smile': 0,
#   'pictures': 0,
#   'thats': 0,
#   'lane': 0,
#   'credit': 0,
#   'later': 0,
#   'told': 0,
#   'felt': 0,
#   'pulled': 0,
#   'hopin': 0,
#   'brain': 0,
#   'breathin': 0,
#   'beg': 0,
#   'shake': 0,
#   'girl': 0,
#   'hed': 0,
#   'hope': 0,
#   'thanks': 0,
#   'sometimes': 0,
#   'hit': 3.2188758248682006,
#   'said': 0,
#   'missing': 0,
#   'unwind': 0,
#   'system': 0,
#   'footprints': 0,
#   'white': 0,
#   'against': 0,
#   'open': 1.3862943611198906,
#   'pumps': 0,
#   'control': 0,
#   'full': 0,
#   'tourist': 0,
#   'drummer': 0,
#   'shame': 0,
#   'bend': 0,
#   'meet': 1.6094379124341003,
#   'realize': 0,
#   'whos': 0,
#   'ballistic': 0,
#   'crazy': 0,
#   'blessing': 0,
#   'say': 0,
#   'me': 0,
#   'beneath': 0,
#   'complete': 2.995732273553991,
#   'snakin': 0,
#   'by': 0,
#   'honky-tonk': 0,
#   'shots': 0,
#   'aftermath': 0,
#   'antidote': 0,
#   'thought': 0,
#   'mind': 0,
#   'shell': 0,
#   'souls': 0,
#   'desert': 2.995732273553991,
#   'try': 0,
#   'truth': 0,
#   'them': 0,
#   'uh': 0,
#   'to': 0.3077597663253029,
#   'blah': 0,
#   'subject': 0,
#   'maybe': 0,
#   'one': 0,
#   'rightful': 0,
#   'extensions': 0,
#   'channel': 0,
#   'attack': 0,
#   'shoulder': 0,
#   'enshrined': 0,
#   'go': 0,
#   'please': 0,
#   'operator': 0,
#   'hear': 0,
#   'always': 0,
#   'brother': 0,
#   'casualty': 0,
#   'clydes': 2.995732273553991,
#   'tendons': 0,
#   'better': 0,
#   'hero': 0,
#   'alive': 0,
#   'sign': 0,
#   'ones': 0,
#   'blindfolded': 0,
#   'youd': 0,
#   'only': 0,
#   'guess': 0,
#   'hes': 3.7942399697717626,
#   'love': 0,
#   'sin': 0,
#   'member': 0,
#   'damn': 0,
#   'rain': 0,
#   'lil': 0,
#   'wouldnt': 0,
#   'chantin': 0,
#   'bet': 0,
#   'broads': 0,
#   'first': 0,
#   'compound': 0,
#   'same': 0,
#   'together': 0,
#   'problem': 2.302585092994046,
#   'phillipe': 0,
#   'juice': 0,
#   'ungbambe': 0,
#   'hol': 0,
#   'nothing': 0,
#   'give': 0,
#   'yaow': 0,
#   'everybody': 0,
#   'goes': 0,
#   'put': 0,
#   'kathleen': 0,
#   'pajamas': 0,
#   'ready': 0,
#   'false': 0,
#   'spinning': 0,
#   'lean': 0,
#   'needs': 0,
#   'kept': 0,
#   'luck': 0,
#   'driving': 0,
#   'good': 1.3862943611198906,
#   'politics': 0,
#   'haunt': 0,
#   'wins': 0,
#   'else': 0,
#   'chill': 0,
#   'swaps': 2.995732273553991,
#   'coons': 0,
#   'beach': 2.995732273553991,
#   'thank': 0,
#   'triggering': 0,
#   'letters': 0,
#   'many': 0,
#   'kickin': 0,
#   'over': 0,
#   'covered': 0,
#   'champaign-urbana': 0,
#   'done': 0,
#   '9': 0,
#   'bullshit': 0,
#   'magnums': 0,
#   'blonde': 0,
#   'high': 0,
#   'beside': 0,
#   'stutter': 0,
#   'cleaver': 0,
#   'plus': 0,
#   'foreman': 0,
#   'genocide': 0,
#   'equal': 0,
#   'butterflies': 0,
#   'reside': 0,
#   'message': 0,
#   'somethings': 1.8971199848858813,
#   'band': 0,
#   'just': 0,
#   'change': 0,
#   'buildin': 0,
#   'survive': 0,
#   'spent': 0,
#   'whole': 0,
#   'myself': 0,
#   'game': 0,
#   'like': 0.43078291609245434,
#   'getting': 0,
#   'hot': 0,
#   'unleash': 0,
#   'fair': 0,
#   'chords': 0,
#   'sleep': 0,
#   'knees': 0,
#   'boat': 0,
#   'waited': 0,
#   'polite': 0,
#   'ya': 0,
#   'friends': 0,
#   'loving': 0,
#   'breaks': 0,
#   'at': 2.0996442489973552,
#   'bleeding': 0,
#   'gift': 0,
#   'perimeter': 0,
#   'running': 0,
#   'amen': 1.8971199848858813,
#   'castin': 0,
#   'flex': 0,
#   'alabama': 0,
#   'switch': 2.302585092994046,
#   'yall': 0,
#   'pow': 0,
#   'ground': 0,
#   'throw': 0,
#   'criminal': 0,
#   'subliminal': 0,
#   'did': 0,
#   'other': 0,
#   'hold': 0,
#   'or': 0,
#   'us': 0,
#   'nobody': 0,
#   'knowing': 0,
#   'ima': 0,
#   'bought': 0,
#   'squad': 0,
#   'anywhere': 0,
#   'maple': 0,
#   'beams': 0,
#   'somebody': 0,
#   'claimed': 0,
#   'heard': 2.302585092994046,
#   'posters': 0,
#   'starts': 0,
#   'buddies': 0,
#   'people': 0,
#   'prophecy': 0,
#   'we': 0,
#   'world': 0,
#   'dog': 0,
#   'flash': 2.995732273553991,
#   'onto': 0,
#   'making': 0,
#   'whip': 0,
#   'want': 0,
#   'wept': 0,
#   'pick-up': 5.991464547107982,
#   'answer': 0,
#   'scope': 0,
#   'knew': 0,
#   'asks': 2.995732273553991,
#   'here': 0,
#   'really': 0,
#   'swore': 0,
#   'small': 0,
#   'og': 0,
#   'slick': 0,
#   'do-do-do-do': 0,
#   'lives': 0,
#   'dreams': 1.8971199848858813,
#   'would': 1.8971199848858813,
#   'falls': 0,
#   'pristine': 0,
#   'enough': 0,
#   'lungs': 0,
#   'may': 0,
#   'children': 0,
#   'hers': 0,
#   'somewhere': 0,
#   'stubborn': 0,
#   'shit': 0,
#   'title': 0,
#   'talk': 0,
#   'draw': 0,
#   'thieving': 2.995732273553991,
#   'pray': 0,
#   'haters': 0,
#   'lose': 0,
#   'now': 1.6094379124341003,
#   'trying': 0,
#   'top': 0,
#   'havent': 0,
#   'bust': 0,
#   'scared': 0,
#   'tend': 0,
#   'engine': 0,
#   'steppin': 0,
#   'money': 1.8971199848858813,
#   'passage': 0,
#   'doin': 0,
#   'swingin': 0,
#   'its': 0.43078291609245434,
#   'dinner': 2.995732273553991,
#   'times': 1.6094379124341003,
#   'dance': 0,
#   'wake': 0,
#   'red-head': 0,
#   'forgotten': 0,
#   'seems': 2.995732273553991,
#   'much': 0,
#   'travel': 0,
#   'aimin': 0,
#   'know-ow': 0,
#   'rodeo': 0,
#   'motherfucker': 0,
#   'bag': 0,
#   'clean': 0,
#   'leaf': 0,
#   'target': 0,
#   'are': 0,
#   'bangs': 2.995732273553991,
#   'comin': 0,
#   'set': 1.6094379124341003,
#   'our': 0,
#   'happy': 2.995732273553991,
#   'surface': 0,
#   'lawless': 0,
#   'herby': 0,
#   'remote': 0,
#   'master': 2.995732273553991,
#   'repeat': 0,
#   'jc': 0,
#   'diddy': 0,
#   'sacrificed': 0,
#   'move': 0,
#   'debt': 0,
#   'i': 0,
#   'status': 0,
#   'mayhem': 0,
#   'six': 0,
#   'knockoff': 0,
#   'nigga': 0,
#   'worse': 0,
#   'standby': 0,
#   'floor': 4.605170185988092,
#   'as': 0,
#   'euphoria': 0,
#   'wrong': 0,
#   'unggudluke': 0,
#   'show': 0,
#   'to—': 0,
#   'rubber': 0,
#   'simply': 0,
#   'clique': 0,
#   'hazy': 0,
#   'sitting': 0,
#   'still': 0,
#   'city': 0,
#   'trees': 0,
#   'wild': 0,
#   'dont': 0,
#   'cocaine': 0,
#   'louisiana': 0,
#   'shoot': 0,
#   'moral': 0,
#   'bars': 0,
#   'make': 0,
#   'places': 0,
#   'niggas': 0,
#   'teach': 0,
#   'tangle': 0,
#   'bodys': 0,
#   "''": 1.6094379124341003,
#   'side': 0,
#   'yous': 0,
#   'swimming': 0,
#   'today': 0,
#   'weaver': 0,
#   'out': 1.4266997757549296,
#   'low': 0,
#   'gates': 0,
#   'valentines': 0,
#   'loved': 0,
#   'big': 1.3862943611198906,
#   'swing': 2.995732273553991,
#   'know-ow-ow': 0,
#   'herb': 0,
#   'ropes': 0,
#   'off': 0,
#   'dead': 0,
#   'every': 1.3862943611198906,
#   'boo': 0,
#   'reverence': 0,
#   'stack': 0,
#   'pedigree': 0,
#   'screaming': 0,
#   'em': 3.2188758248682006,
#   'coast': 0,
#   'smoke': 0,
#   'radion': 0,
#   'words': 0,
#   'weekend': 0,
#   'after': 0,
#   'check': 0,
#   'mothafuck': 0,
#   'pack': 0,
#   'push': 0,
#   'meant': 0,
#   'sand': 0,
#   'blackin': 0,
#   'hours': 0,
#   'mopped': 0,
#   'sound': 0,
#   'size': 0,
#   'trinity': 0,
#   'die': 0,
#   'depending': 0,
#   'righteous': 0,
#   'doubt': 0,
#   '500': 0,
#   'electorial': 0,
#   'scarface': 0,
#   'roar': 0,
#   'relief': 0,
#   'emergency': 0,
#   'chitty': 0,
#   'whippin': 0,
#   'where': 0,
#   'prowl': 0,
#   'confetti': 0,
#   'rest': 0,
#   'puddles': 0,
#   'dying': 0,
#   'killmonger': 0,
#   'phone': 0,
#   'car': 1.6094379124341003,
#   'work': 0,
#   'am': 0,
#   'gone': 2.995732273553991,
#   'lasers': 0,
#   'zero': 0,
#   'probably': 0,
#   'sea': 0,
#   'straight': 0,
#   'ears': 0,
#   'new': 0,
#   'swear': 0,
#   'clutchin': 0,
#   'drive': 0,
#   'hundred': 0,
#   'promised': 0,
#   'score': 2.302585092994046,
#   'long': 0,
#   'everyone': 0,
#   'everything': 0,
#   'endorsin': 0,
#   'fingerprints': 0,
#   'finally': 0,
#   'friday': 2.302585092994046,
#   'theres': 1.0498221244986776,
#   'cyborg': 0,
#   'warfare': 0,
#   'guyana': 0,
#   'such': 0,
#   'ralphs': 0,
#   'nothin': 0,
#   'is': 0.44628710262841953,
#   'movin': 0,
#   'karaoke': 0,
#   'two': 2.772588722239781,
#   'paraplegic': 0,
#   'views': 0,
#   'miss': 0,
#   'knows': 1.8971199848858813,
#   'four': 3.2188758248682006,
#   'beast': 0,
#   'chase': 0,
#   'seen': 2.302585092994046,
#   'ta': 0,
#   'opps': 0,
#   'through': 1.0498221244986776,
#   'strings': 0,
#   'night-call': 0,
#   'ad-lib': 0,
#   'little': 0,
#   'those': 0,
#   'doorsteps': 0,
#   'sneak': 0,
#   'sundown': 0,
#   'country': 0,
#   'neighbor': 0,
#   'syrupd': 0,
#   'soon': 0,
#   'goin': 0,
#   'state': 0,
#   'last': 2.302585092994046,
#   'balance': 0,
#   'cowboys': 0,
#   'rollin': 0,
#   '87': 0,
#   'bypass': 0,
#   'stretch': 0,
#   'gosh': 0,
#   'god': 0,
#   'cause': 0,
#   'gas': 0,
#   'thirty': 0,
#   'ungbhasobhe': 0,
#   'sinister': 0,
#   'angel': 0,
#   'panther': 0,
#   'morgue': 0,
#   'look': 0,
#   'jumpin': 0,
#   'realest': 0,
#   'blind': 0,
#   'two-thirds': 0,
#   'wreck': 0,
#   'whoever': 0,
#   'important': 0,
#   'ocean': 0,
#   'center-attention': 0,
#   'japan': 0,
#   'home': 0,
#   'traffic': 0,
#   'machine': 0,
#   'indiana': 0,
#   'dial': 0,
#   'gets': 2.302585092994046,
#   'gave': 0,
#   'keep': 0,
#   'come': 0,
#   'had': 0,
#   'whoa': 0,
#   'name': 0,
#   'topped-off': 0,
#   'section': 0,
#   'figurines': 0,
#   'nerve': 0,
#   'that': 0.3250378589955499,
#   'what': 0,
#   'corrupt': 0,
#   'ship': 0,
#   'hoped': 0,
#   'needle': 0,
#   'girls': 0,
#   'well': 0,
#   'nightstand': 0,
#   'his': 0,
#   'scenes': 0,
#   'theyre': 3.2188758248682006,
#   'sky': 0,
#   'beam': 0,
#   'beat': 0,
#   'feelings': 0,
#   'opinion': 0,
#   'miracle': 0,
#   'building': 0,
#   'occurred': 0,
#   'brothers': 0,
#   'pull': 0,
#   'admission': 0,
#   'anything': 0,
#   'taxi': 0,
#   'pain': 0,
#   'even': 0,
#   'wan': 0,
#   'thinking': 0,
#   'thunder': 0,
#   'lights': 0,
#   'were': 1.3862943611198906,
#   '83': 0,
#   'bullet': 0,
#   'crash': 0,
#   'integrity': 0,
#   'somethin': 0,
#   'cup': 0,
#   'rejoin': 0,
#   'pimp': 0,
#   'sands': 2.995732273553991,
#   'has': 0,
#   'changed': 0,
#   'eyy': 0,
#   'no': 0,
#   'away': 1.2039728043259361,
#   'song': 0,
#   'passed': 0,
#   'this': 0,
#   'hollow': 0,
#   'word': 0,
#   '4': 0,
#   'your': 0,
#   'cars': 0,
#   'again': 1.6094379124341003,
#   'stars': 0,
#   'woah': 0,
#   'laughing': 0,
#   'grindin': 0,
#   'belittles': 0,
#   'queen': 0,
#   'worth': 0,
#   'ear': 0,
#   'right': 1.2039728043259361,
#   'circumstance': 0,
#   'havana': 0,
#   'fourteen': 0,
#   'must': 2.995732273553991,
#   'dirty': 0,
#   'friend': 0,
#   'guards': 2.995732273553991,
#   'lox': 0,
#   'walked': 0,
#   'hang': 0,
#   'whiskey': 0,
#   'blue': 0,
#   'runneth': 0,
#   'hard': 0,
#   'deaf': 0,
#   'faith': 0,
#   'showing': 0,
#   'another': 0,
#   'broken': 0,
#   'kitchen': 0,
#   'chess': 0,
#   'borderline': 0,
#   'jack': 0,
#   'absent': 0,
#   'armored': 2.995732273553991,
#   ...}]

# %% [markdown]
# ## **Visualizing our Vectorizations**

# %%
vocab = list(tf_idf_all_docs[0].keys())
num_dims = len(vocab)
print(f"Number of Dimensions: {num_dims}")
# Out:
# Number of Dimensions: 1342

# %% [markdown]
# There are too many dimensions for us to visualize! In order to make it understandable to human eyes, we'll need to reduce it to 2 or 3 dimensions.
#
# To do this, we'll use a technique called **_t-SNE_** (short for _t-Stochastic Neighbors Embedding_).
#
# First, we need to pull the words out of the dictionaries stored in `tf_idf_all_docs` so that only the values remain, and store them in lists instead of dictionaries.  This is because the t-SNE only works with array-like objects, not dictionaries.
#
# In the cell below, create a list of lists that contains a list representation of the values of each of the dictionaries stored in `tf_idf_all_docs`.  The same structure should remain -- e.g. the first list should contain only the values that were in the first dictionary in `tf_idf_all_docs`, and so on.

# %%
tf_idf_vals_list = []

for i in tf_idf_all_docs:
    tf_idf_vals_list.append(list(i.values()))

tf_idf_vals_list[0][:10]
# Out:
# [0, 11.982929094215963, 0, 0, 0, 0, 0, 2.995732273553991, 0, 0]

# %% [markdown]
# Now that we have only the values, we can use the `TSNE()` class from `sklearn` to transform our data appropriately. In the cell below, instantiate `TSNE()` with the following arguments:
# - `n_components=3` (so we can compare 2 vs 3 components when graphing)
# - `perplexity=19` (the highest number of neighbors explored given the size of our dataset)
# - `learning_rate=200` (a higher learning rate than using 'auto', to avoid getting stuck in a local minimum)
# - `init='random'` (so SKLearn will randomize the initialization)
# - `random_state=13` (so that random initialization won't be TOO random)
#
# Then, use the created object's `.fit_transform()` method to transform the data stored in `tf_idf_vals_list` into 3-dimensional data.  Then, inspect the newly transformed data to confirm that it has the correct dimensionality.

# %%
t_sne_object_3d = TSNE(n_components = 3, 
                       perplexity = 19,
                       learning_rate = 200,
                       init = 'random',
                       random_state = 13)


transformed_data_3d = t_sne_object_3d.fit_transform(np.array(tf_idf_vals_list))
transformed_data_3d
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-954bec26b61b> in <module>
#       6
#       7
# ----> 8 transformed_data_3d = t_sne_object_3d.fit_transform(np.array(tf_idf_vals_list))
#       9 transformed_data_3d
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\utils\_set_output.py in wrapped(self, X, *args, **kwargs)
#     155     @wraps(f)
#     156     def wrapped(self, X, *args, **kwargs):
# --> 157         data_to_wrap = f(self, X, *args, **kwargs)
#     158         if isinstance(data_to_wrap, tuple):
#     159             # only wrap the first output for cross decomposition
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\manifold\_t_sne.py in fit_transform(self, X, y)
#    1109         """
#    1110         self._check_params_vs_input(X)
# -> 1111         embedding = self._fit(X)
#    1112         self.embedding_ = embedding
#    1113         return self.embedding_
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\manifold\_t_sne.py in _fit(self, X, skip_num_points)
#     950
#     951             t0 = time()
# --> 952             distances_nn = knn.kneighbors_graph(mode="distance")
#     953             duration = time() - t0
#     954             if self.verbose:
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\neighbors\_base.py in kneighbors_graph(self, X, n_neighbors, mode)
#     984
#     985         elif mode == "distance":
# --> 986             A_data, A_ind = self.kneighbors(X, n_neighbors, return_distance=True)
#     987             A_data = np.ravel(A_data)
#     988
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     820         )
#     821         if use_pairwise_distances_reductions:
# --> 822             results = ArgKmin.compute(
#     823                 X=X,
#     824                 Y=self._fit_X,
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py in compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     257         """
#     258         if X.dtype == Y.dtype == np.float64:
# --> 259             return ArgKmin64.compute(
#     260                 X=X,
#     261                 Y=Y,
#
# sklearn\metrics\_pairwise_distances_reduction\_argkmin.pyx in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\utils\fixes.py in threadpool_limits(limits, user_api)
#      72         return controller.limit(limits=limits, user_api=user_api)
#      73     else:
# ---> 74         return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#      75
#      76
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in __init__(self, limits, user_api)
#     169             self._check_params(limits, user_api)
#     170
# --> 171         self._original_info = self._set_threadpool_limits()
#     172
#     173     def __enter__(self):
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in _set_threadpool_limits(self)
#     266             return None
#     267
# --> 268         modules = _ThreadpoolInfo(prefixes=self._prefixes,
#     269                                   user_api=self._user_api)
#     270         for module in modules:
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in __init__(self, user_api, prefixes, modules)
#     338
#     339             self.modules = []
# --> 340             self._load_modules()
#     341             self._warn_if_incompatible_openmp()
#     342         else:
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in _load_modules(self)
#     371             self._find_modules_with_dyld()
#     372         elif sys.platform == "win32":
# --> 373             self._find_modules_with_enum_process_module_ex()
#     374         else:
#     375             self._find_modules_with_dl_iterate_phdr()
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in _find_modules_with_enum_process_module_ex(self)
#     483
#     484                 # Store the module if it is supported and selected
# --> 485                 self._make_module_from_path(filepath)
#     486         finally:
#     487             kernel_32.CloseHandle(h_process)
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in _make_module_from_path(self, filepath)
#     513             if prefix in self.prefixes or user_api in self.user_api:
#     514                 module_class = globals()[module_class]
# --> 515                 module = module_class(filepath, prefix, user_api, internal_api)
#     516                 self.modules.append(module)
#     517
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in __init__(self, filepath, prefix, user_api, internal_api)
#     604         self.internal_api = internal_api
#     605         self._dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
# --> 606         self.version = self.get_version()
#     607         self.num_threads = self.get_num_threads()
#     608         self._get_extra_info()
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in get_version(self)
#     644                              lambda: None)
#     645         get_config.restype = ctypes.c_char_p
# --> 646         config = get_config().split()
#     647         if config[0] == b"OpenBLAS":
#     648             return config[1].decode("utf-8")
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
t_sne_object_2d = TSNE(n_components = 2, 
                       perplexity = 19,
                       learning_rate = 200,
                       init = 'random', 
                       random_state = 13)
transformed_data_2d = t_sne_object_2d.fit_transform(np.array(tf_idf_vals_list))
transformed_data_2d
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-0a4b070d69c3> in <module>
#       4                        init = 'random',
#       5                        random_state = 13)
# ----> 6 transformed_data_2d = t_sne_object_2d.fit_transform(np.array(tf_idf_vals_list))
#       7 transformed_data_2d
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\utils\_set_output.py in wrapped(self, X, *args, **kwargs)
#     155     @wraps(f)
#     156     def wrapped(self, X, *args, **kwargs):
# --> 157         data_to_wrap = f(self, X, *args, **kwargs)
#     158         if isinstance(data_to_wrap, tuple):
#     159             # only wrap the first output for cross decomposition
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\manifold\_t_sne.py in fit_transform(self, X, y)
#    1109         """
#    1110         self._check_params_vs_input(X)
# -> 1111         embedding = self._fit(X)
#    1112         self.embedding_ = embedding
#    1113         return self.embedding_
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\manifold\_t_sne.py in _fit(self, X, skip_num_points)
#     950
#     951             t0 = time()
# --> 952             distances_nn = knn.kneighbors_graph(mode="distance")
#     953             duration = time() - t0
#     954             if self.verbose:
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\neighbors\_base.py in kneighbors_graph(self, X, n_neighbors, mode)
#     984
#     985         elif mode == "distance":
# --> 986             A_data, A_ind = self.kneighbors(X, n_neighbors, return_distance=True)
#     987             A_data = np.ravel(A_data)
#     988
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     820         )
#     821         if use_pairwise_distances_reductions:
# --> 822             results = ArgKmin.compute(
#     823                 X=X,
#     824                 Y=self._fit_X,
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py in compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     257         """
#     258         if X.dtype == Y.dtype == np.float64:
# --> 259             return ArgKmin64.compute(
#     260                 X=X,
#     261                 Y=Y,
#
# sklearn\metrics\_pairwise_distances_reduction\_argkmin.pyx in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\utils\fixes.py in threadpool_limits(limits, user_api)
#      72         return controller.limit(limits=limits, user_api=user_api)
#      73     else:
# ---> 74         return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#      75
#      76
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in __init__(self, limits, user_api)
#     169             self._check_params(limits, user_api)
#     170
# --> 171         self._original_info = self._set_threadpool_limits()
#     172
#     173     def __enter__(self):
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in _set_threadpool_limits(self)
#     266             return None
#     267
# --> 268         modules = _ThreadpoolInfo(prefixes=self._prefixes,
#     269                                   user_api=self._user_api)
#     270         for module in modules:
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in __init__(self, user_api, prefixes, modules)
#     338
#     339             self.modules = []
# --> 340             self._load_modules()
#     341             self._warn_if_incompatible_openmp()
#     342         else:
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in _load_modules(self)
#     371             self._find_modules_with_dyld()
#     372         elif sys.platform == "win32":
# --> 373             self._find_modules_with_enum_process_module_ex()
#     374         else:
#     375             self._find_modules_with_dl_iterate_phdr()
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in _find_modules_with_enum_process_module_ex(self)
#     483
#     484                 # Store the module if it is supported and selected
# --> 485                 self._make_module_from_path(filepath)
#     486         finally:
#     487             kernel_32.CloseHandle(h_process)
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in _make_module_from_path(self, filepath)
#     513             if prefix in self.prefixes or user_api in self.user_api:
#     514                 module_class = globals()[module_class]
# --> 515                 module = module_class(filepath, prefix, user_api, internal_api)
#     516                 self.modules.append(module)
#     517
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in __init__(self, filepath, prefix, user_api, internal_api)
#     604         self.internal_api = internal_api
#     605         self._dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
# --> 606         self.version = self.get_version()
#     607         self.num_threads = self.get_num_threads()
#     608         self._get_extra_info()
#
# c:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\threadpoolctl.py in get_version(self)
#     644                              lambda: None)
#     645         get_config.restype = ctypes.c_char_p
# --> 646         config = get_config().split()
#     647         if config[0] == b"OpenBLAS":
#     648             return config[1].decode("utf-8")
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
kendrick_3d = transformed_data_3d[:10]
k3_x = [i[0] for i in kendrick_3d]
k3_y = [i[1] for i in kendrick_3d]
k3_z = [i[2] for i in kendrick_3d]

garth_3d = transformed_data_3d[10:]
g3_x = [i[0] for i in garth_3d]
g3_y = [i[1] for i in garth_3d]
g3_z = [i[2] for i in garth_3d]

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(k3_x, k3_y, k3_z, c='b', s=60, label='Kendrick')
ax.scatter(g3_x, g3_y, g3_z, c='red', s=60, label='Garth')
ax.view_init(40,10)
ax.legend()
plt.show()

kendrick_2d = transformed_data_2d[:10]
k2_x = [i[0] for i in kendrick_2d]
k2_y = [i[1] for i in kendrick_2d]

garth_2d = transformed_data_2d[10:]
g2_x = [i[0] for i in garth_2d]
g2_y = [i[1] for i in garth_2d]

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(222)
ax.scatter(k2_x, k2_y, c='b', label='Kendrick')
ax.scatter(g2_x, g2_y, c='red', label='Garth')
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-40b7cd1487d8> in <module>
# ----> 1 kendrick_3d = transformed_data_3d[:10]
#       2 k3_x = [i[0] for i in kendrick_3d]
#       3 k3_y = [i[1] for i in kendrick_3d]
#       4 k3_z = [i[2] for i in kendrick_3d]
#       5
#
# NameError: name 'transformed_data_3d' is not defined

# %% [markdown]
# Both graphs show a basic trend among the red and blue dots, although the 3-dimensional
# graph is more informative than the 2-dimensional graph. We see a separation between the
# two artists because they both have words that they use, but the other artist does not.
#
# The words in each song that are common to both are reduced to very small numbers or to 0,
# because of the log operation in the IDF function.  This means that the elements of each
# song vector with the highest values will be the ones that have words that are unique to
# that specific document, or at least are rarely used in others.
